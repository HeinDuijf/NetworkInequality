# %% [markdown]
# # Variation methods

# %% [markdown]
# Main contribution of the paper:
#
# - Methodological contribution of empirical robustness for _network_ epistemology.
#
# Key challenge:
#
# - Test whether inequality (or some other network feature such as density, clustering, or diameter) increases reliability (or some other metric such as speed).
# - Counterfactual: had the network been more equal, the group would have been more reliable.
# - This requires us to identify networks that differ in their inequality but are otherwise maximally similar.
# - We consider three network features: density, clustering, and degree inequality. So networks that have the similar density, clustering and degree inequality are considered maximally similar. (I left out diameter here.)
#
# To achieve this, we develop some variation methods. The main goals for these variation methods are:
#
# 1. Control: Ability to tinker with specific network features (density, inequality, clustering)
# 2. Simplicity
# 3. Computational tractability
# 4. Link to (individualistic) intervention
#
# There are two types of variation methods:
#
# 1. Possibly complex variation methods that can be used to produce networks with specific network properties (density, inequality, clustering), i.e., high control
# 2. Intuitive and simple variation methods that yield a lower degree of control over the specific network properties (density, inequality, clustering)
#
# The basic ideas in these variation methods are the following:
#
# 1. Density
#     - Increase by adding edges
#     - Keep constant by rewiring edges
#     - Decrease by removing edges [not implemented]
# 2. Clustering
#     - Note: the local clustering coefficient of a given node basically is the number of triangles that pass by that node divided by the number of possible triangles that pass by that node.
#     - Increase by adding edges that create new triangles
#     - Keep constant ???
#     - Decrease by removing edges from existing triangles
# 3. Inequality
#     - Decrease by adding edges randomly (following the uniform degree distribution)
#     - Keep constant by adding edges following the original degree distribution (i.e., that of the PUD network)
#     - Increase by (a) sequentially adding edges preferentially, or  (b) by adding edges following a degree distribution that is more unequal than the original one [neither implemented]
#
# ## Hop over to Outcomes section to see the results of the different variation methods
#
# ## Simple variation methods
#
# ### Equalizers: tinker with inequality
#
# 1. `randomize_network`: Randomly rewire edges (following the uniform degree distribution) [THIS IS WHAT WE CURRENTLY DO]
#     - Density $=$
#     - Clustering $\downarrow$
#     - Inequality $\downarrow$
# 2. `equalize`: Rewire triangles: Take a triangle, take a node in the triangle, remove the edge in the triangle that does not contain the node, then add a random new edge that creates a new triangle that passed by the node. (The goal was to keep clustering somewhat equal, while increasing equality.)
#     - Density $=$
#     - Clustering $\approx \downarrow$
#     - Inequality $\downarrow$
#
# ### Densify
# 1. [not implemented] Randomly add edges (following the uniform degree distribution)
#     - Expectations
#         - Density $\uparrow$
#         - Clustering $\downarrow$
#         - Inequality $\downarrow$
# 2. `densify`: Add edges following the original degree distribution
#     - Density $\uparrow$
#     - Clustering $\downarrow$
#     - Inequality $=$
# 3. `cluster`: Add edges that create new triangles (taking into account the original degree distribution)
#     - Density $\uparrow$
#     - Clustering $\Uparrow$
#     - Inequality $\approx$
#
# ### Clustering
# 1. `decluster`: Remove edges from existing triangles and add new edge following the original degree distribution
#     - Density $=$
#     - Clustering $\Downarrow$
#     - Inequality $\approx\downarrow$
#
#
# ## Complex variation methods
#
# 1. `densify_fancy`: Add edges in such a way to attempt to reach a target clustering coefficient and a target degree distribution (original or uniform).
#     - Basically, the algorithm checks whether the target clustering coefficient has been reached. If not, it adds an edge that increases clustering. If yes, it adds a new edge following the target degree distribution.
#     - **Computationally costly**: after an edge is added, the algorithm calculates the clustering coefficient of the new network, which is computationally costly to an unacceptable degree (I think).
#     - **High degree of control**, especially regarandoming the clustering coefficient: For example, can be used to achieve the following:
#         1. Only increase density
#             - Density $\uparrow$
#             - Clustering $=$
#             - Inequality $=$
#         2. Increase density and decrease inequality
#             - Density $\uparrow$
#             - Clustering $=$
#             - Inequality $\downarrow$
# 2. `densify_fancy_speed_up`: This method basically works the same as `densify_fancy`, but has a significant speed up. Instead of calculating the average clustering coefficient whenever an edge is added, we only calculate the new local clusterinf coefficient for nodes that are affected by the newly added edge.
#     - **Computationally not cheap**: although the algorithm is much quicker than `densify_fancy`, it still takes some time. I expect that the computational costs are acceptable.
#     - **High control**, especially regarandoming the clustering coefficient.
# 3. `densify_semi_fancy`: Add edges either to increase clustering or following the target degree distribution — with a fixed probability.
#     - Basically, the algorithm throws a (biased) coin to determine whether it will add an edge that increases clustering or add one following the target degree distribution.
#     - Computationally fast. Relies on a biased coin toss instead of calculating the clustering coefficient. The drawback is that the clustering coefficient will change to some degree.
#     - Pretty high degree of control.
#
#
# - Note: we could keep the density fixed by first removing a number of edges and then using `densify_fancy` or `densify_semi_fancy` to add the same number of edges.
#
# ## Thoughts and observations
#
# - I was surprised to learn that both the in-degree and the out-degree distributions of the PUD network are scale free. However, they are not neatly correlated. Nonetheless, my suspicion is that there is a pattern between an agent’s number of publication and both its in-degree and its out-degree.
# - I was surprised to learn that the clustering coefficient is not based on directed graphs (`nx.average_clustering`).
# - In a sense, we have currently only implemented the target degree distribution of the degree distribution of the input network (the PUD network) or the uniform distribution. We could consider other degree distributions (i.e., an unequal distribution that flips the original degree distribution)
# -

# %% [markdown]
# ## Setup

# %%
from imports import *
from network_utils import *
# import random as random

network_pud: nx.DiGraph = dill.load(open('empirical_networks/pud_final.pkl', 'rb'))

# %% [markdown]
# ## Randomize

# %%
random_net_1 = randomize_network(network_pud, p_rewiring=0.1)
random_net_2 = randomize_network(network_pud, p_rewiring=0.2)
random_net_3 = randomize_network(network_pud, p_rewiring=0.3)
random_net_4 = randomize_network(network_pud, p_rewiring=0.4)
random_net_5 = randomize_network(network_pud, p_rewiring=0.5)

# %%
data_random = {
    "network": ["original", "random_10%", "random_20%", "random_30%", "random_40%", "random_50%"],
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(random_net_1, directed=True),
        calculate_degree_gini(random_net_2, directed=True),
        calculate_degree_gini(random_net_3, directed=True),
        calculate_degree_gini(random_net_4, directed=True),
        calculate_degree_gini(random_net_5, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(random_net_1),
        nx.average_clustering(random_net_2),
        nx.average_clustering(random_net_3),
        nx.average_clustering(random_net_4),
        nx.average_clustering(random_net_5)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(random_net_1),
        nx.density(random_net_2),
        nx.density(random_net_3),
        nx.density(random_net_4),
        nx.density(random_net_5)
    ]
}
df_random = pd.DataFrame(data_random)
df_random
# Out:
#       network  degree_gini  clustering_coefficient   density
# 0    original     0.722814                0.117170  0.000735
# 1  random_10%     0.671672                0.073970  0.000735
# 2  random_20%     0.615289                0.048422  0.000735
# 3  random_30%     0.562563                0.031578  0.000735
# 4  random_40%     0.507131                0.019903  0.000735
# 5  random_50%     0.456154                0.011539  0.000735

# %% [markdown]
# ## Equalize

# %%
equalized_net_1 = equalize(network_pud, n=1000)
equalized_net_2 = equalize(network_pud, n=2000)
equalized_net_3 = equalize(network_pud, n=3000)
equalized_net_4 = equalize(network_pud, n=4000)
equalized_net_5 = equalize(network_pud, n=5000)

# %%
data_equalize = {
    "network": ["original", "equalized_1000", "equalized_2000", "equalized_3000", "equalized_4000", "equalized_5000"],
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(equalized_net_1, directed=True),
        calculate_degree_gini(equalized_net_2, directed=True),
        calculate_degree_gini(equalized_net_3, directed=True),
        calculate_degree_gini(equalized_net_4, directed=True),
        calculate_degree_gini(equalized_net_5, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(equalized_net_1),
        nx.average_clustering(equalized_net_2),
        nx.average_clustering(equalized_net_3),
        nx.average_clustering(equalized_net_4),
        nx.average_clustering(equalized_net_5)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(equalized_net_1),
        nx.density(equalized_net_2),
        nx.density(equalized_net_3),
        nx.density(equalized_net_4),
        nx.density(equalized_net_5)
    ]
}

df_equalize = pd.DataFrame(data_equalize)
df_equalize
# Out:
#           network  degree_gini  clustering_coefficient   density
# 0        original     0.722814                0.117170  0.000735
# 1  equalized_1000     0.712783                0.107457  0.000735
# 2  equalized_2000     0.702656                0.103614  0.000735
# 3  equalized_3000     0.695547                0.098000  0.000735
# 4  equalized_4000     0.689827                0.094092  0.000735
# 5  equalized_5000     0.684853                0.089313  0.000735

# %% [markdown]
# ## Densify

# %%
densify_net_1 = densify_network(network_pud, n_edges=1000)
print("Done")
densify_net_2 = densify_network(network_pud, n_edges=2000)
print("Done")
densify_net_3 = densify_network(network_pud, n_edges=3000)
print("Done")
densify_net_4 = densify_network(network_pud, n_edges=4000)
print("Done")
densify_net_5 = densify_network(network_pud, n_edges=5000)
print("Done")
# Out:
# Done
# Done
# Done
# Done
# Done

# %%
out_degrees_pud = sorted(list(dict(network_pud.out_degree()).values()), reverse=True)

out_degrees_densify_1 = sorted(list(dict(densify_net_1.out_degree()).values()), reverse=True)
out_degrees_densify_2 = sorted(list(dict(densify_net_2.out_degree()).values()), reverse=True)
out_degrees_densify_3 = sorted(list(dict(densify_net_3.out_degree()).values()), reverse=True)
out_degrees_densify_4 = sorted(list(dict(densify_net_4.out_degree()).values()), reverse=True)
out_degrees_densify_5 = sorted(list(dict(densify_net_5.out_degree()).values()), reverse=True)

data = zip(
    out_degrees_pud, 
    out_degrees_densify_1, out_degrees_densify_2, out_degrees_densify_3, out_degrees_densify_4, out_degrees_densify_5)

df = pd.DataFrame(data, columns=["PUD", "Densified1", "Densified2", "Densified3", "Densified4", "Densified5"])

fig = sns.lineplot(df)
fig.set_yscale("log")
fig.set_xscale("log")

# %%
in_degrees_pud = sorted(list(dict(network_pud.in_degree()).values()), reverse=True)

in_degrees_densify_1 = sorted(list(dict(densify_net_1.in_degree()).values()), reverse=True)
in_degrees_densify_2 = sorted(list(dict(densify_net_2.in_degree()).values()), reverse=True)
in_degrees_densify_3 = sorted(list(dict(densify_net_3.in_degree()).values()), reverse=True)
in_degrees_densify_4 = sorted(list(dict(densify_net_4.in_degree()).values()), reverse=True)
in_degrees_densify_5 = sorted(list(dict(densify_net_5.in_degree()).values()), reverse=True)

data = zip(
    in_degrees_pud, 
    in_degrees_densify_1, in_degrees_densify_2, in_degrees_densify_3, in_degrees_densify_4, in_degrees_densify_5)

df = pd.DataFrame(data, columns=["PUD", "Densified1", "Densified2", "Densified3", "Densified4", "Densified5"])

fig = sns.lineplot(df)
fig.set_yscale("log")
fig.set_xscale("log")

# %%
data_densify = {
    "network": ["original", "densified_1000", "densified_2000", "densified_3000", "densified_4000", "densified_5000"],
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(densify_net_1, directed=True),
        calculate_degree_gini(densify_net_2, directed=True),
        calculate_degree_gini(densify_net_3, directed=True),
        calculate_degree_gini(densify_net_4, directed=True),
        calculate_degree_gini(densify_net_5, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(densify_net_1),
        nx.average_clustering(densify_net_2),
        nx.average_clustering(densify_net_3),
        nx.average_clustering(densify_net_4),
        nx.average_clustering(densify_net_5)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(densify_net_1),
        nx.density(densify_net_2),
        nx.density(densify_net_3),
        nx.density(densify_net_4),
        nx.density(densify_net_5)
    ]
}

df_densify = pd.DataFrame(data_densify)
df_densify
# Out:
#           network  degree_gini  clustering_coefficient   density
# 0        original     0.722814                0.117170  0.000735
# 1  densified_1000     0.724220                0.110193  0.000768
# 2  densified_2000     0.724283                0.102803  0.000801
# 3  densified_3000     0.726149                0.097371  0.000834
# 4  densified_4000     0.726985                0.089387  0.000867
# 5  densified_5000     0.725842                0.085490  0.000900

# %%
p_increase_clustering = 0.33

densify_semi_1 = densify_semi_fancy(
    network_pud, n_edges=1000, p_increase_clustering=p_increase_clustering, target_degree_dist="uniform",
)
densify_semi_2 = densify_semi_fancy(
    network_pud, n_edges=2000, p_increase_clustering=p_increase_clustering, target_degree_dist="uniform",
)
densify_semi_3 = densify_semi_fancy(
    network_pud, n_edges=3000, p_increase_clustering=p_increase_clustering, target_degree_dist="uniform",
)
densify_semi_4 = densify_semi_fancy(
    network_pud, n_edges=4000, p_increase_clustering=p_increase_clustering, target_degree_dist="uniform",
)
densify_semi_5 = densify_semi_fancy(
    network_pud, n_edges=5000, p_increase_clustering=p_increase_clustering, target_degree_dist="uniform",
)
# Out:
# 331 edges added to increase clustering
# 669 edges added based on uniform degree distribution
# 637 edges added to increase clustering
# 1,363 edges added based on uniform degree distribution
# 1,045 edges added to increase clustering
# 1,955 edges added based on uniform degree distribution
# 1,278 edges added to increase clustering
# 2,722 edges added based on uniform degree distribution
# 1,685 edges added to increase clustering
# 3,315 edges added based on uniform degree distribution

# %%
data_densify_semi = {
    "network": [
        "original", 
        "densified_semi_fancy_1000", 
        "densified_semi_fancy_2000", 
        "densified_semi_fancy_3000", 
        "densified_semi_fancy_4000", 
        "densified_semi_fancy_5000"
    ],
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(densify_semi_1, directed=True),
        calculate_degree_gini(densify_semi_2, directed=True),
        calculate_degree_gini(densify_semi_3, directed=True),
        calculate_degree_gini(densify_semi_4, directed=True),
        calculate_degree_gini(densify_semi_5, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(densify_semi_1),
        nx.average_clustering(densify_semi_2),
        nx.average_clustering(densify_semi_3),
        nx.average_clustering(densify_semi_4),
        nx.average_clustering(densify_semi_5)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(densify_semi_1),
        nx.density(densify_semi_2),
        nx.density(densify_semi_3),
        nx.density(densify_semi_4),
        nx.density(densify_semi_5)
    ]
}

df_densify_semi = pd.DataFrame(data_densify_semi)
df_densify_semi
# Out:
#                      network  degree_gini  clustering_coefficient   density
# 0                   original     0.722814                0.117170  0.000735
# 1  densified_semi_fancy_1000     0.705396                0.119901  0.000766
# 2  densified_semi_fancy_2000     0.686549                0.118471  0.000796
# 3  densified_semi_fancy_3000     0.672463                0.117202  0.000825
# 4  densified_semi_fancy_4000     0.654503                0.110578  0.000857
# 5  densified_semi_fancy_5000     0.641581                0.104283  0.000884

# %%
def densify_fancy(
    net: nx.DiGraph, n_edges: int, target_degree_dist: str = "original", target_clustering: float = None,
) -> nx.DiGraph:
    """
    Densifies a directed network by adding new edges to increase its density, 
    while optionally targeting a specific degree distribution and clustering coefficient.
    Priority is given to targeting the specified clustering coefficient.

    Parameters
    ----------
    net : nx.DiGraph
        The original directed network to densify.
    n_edges : int
        The number of edges to add.
    target_degree_dist : str, optional
        The target degree distribution for new edges. 
        "original" preserves the original degree distribution, 
        "uniform" assigns equal probability to all nodes. Default is "original".
    target_clustering : float, optional
        The desired average clustering coefficient. If None, uses the original network's clustering.

    Returns
    -------
    nx.DiGraph
        A new directed network with increased density and optionally modified clustering/degree distribution.
    """
    
    # Create a copy of the original network
    net_new = copy.deepcopy(net)
    
    if target_clustering is None:
        target_clustering = nx.average_clustering(net)
    if target_degree_dist == "original":
        # Use the original degree distribution
        out_degrees = dict(net.out_degree())
        in_degrees = dict(net.in_degree())
    if target_degree_dist == "uniform":
        out_degrees = {node: 1 for node in net.nodes()}
        in_degrees = {node: 1 for node in net.nodes()}

    # Add edges in neighborhoods
    n_edges_added = 0
    edges_added_clustering = 0
    edges_added_degree_dist = 0
    new_clustering = nx.average_clustering(net_new)
    while n_edges_added < n_edges:
        if new_clustering < target_clustering:
            # Add new edge to increase clustering
            node = random.choice(list(net.nodes()))
            neighbors = list(net.predecessors(node)) + list(net.successors(node))
            out_degrees_neighbors = {node: out_degrees[node] for node in neighbors}
            in_degrees_neighbors = {node: in_degrees[node] for node in neighbors}
            out_weights = out_degrees_neighbors.values()
            if all(out_weights) == 0:
                out_weights = np.ones(len(out_degrees_neighbors.keys()))
            in_weights = in_degrees_neighbors.values()
        
            if all(in_weights) == 0:
                in_weights = np.ones(len(in_degrees_neighbors.keys()))
            
            sources = random.choices(list(out_degrees_neighbors.keys()), weights=out_weights, k=10)
            targets = random.choices(list(in_degrees_neighbors.keys()), weights=in_weights, k=10)
            possible_edges = [
                (source, target) for source in sources for target in targets
                if source != target and not net_new.in_edges(source, target)
            ]
            if possible_edges != []:
                new_edge = random.choice(possible_edges)
                n_edges_added += 1
                net_new.add_edge(*new_edge)
                new_clustering = nx.average_clustering(net_new)
                edges_added_clustering += 1
        else:
            # Add new edge based on target degree distribution
            sources_sample = random.choices(list(out_degrees.keys()), weights=out_degrees.values(), k=10)
            targets_sample = random.choices(list(in_degrees.keys()), weights=in_degrees.values(), k=10)
            edge_sample = [
                (source, target) 
                for source in sources_sample 
                for target in targets_sample 
                if source != target and not net_new.has_edge(source, target)]
            if edge_sample != []:
                new_edge = random.choice(edge_sample) # Throws an error if no edges are available
                n_edges_added += 1
                net_new.add_edge(*new_edge)
                new_clustering = nx.average_clustering(net_new)
                edges_added_degree_dist += 1
        print(f"{n_edges_added=:,} edges added")
    print(f"{edges_added_clustering:,} edges added to increase clustering")
    print(f"{edges_added_degree_dist:,} edges added based on {target_degree_dist} degree distribution")
    return net_new

# %%
densify_fancy_01 = densify_fancy(network_pud, n_edges=100, target_degree_dist="uniform") # Approx 25 seconds
# Out:
# n_edges_added=1 edges added
# n_edges_added=1 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=3 edges added
# n_edges_added=4 edges added
# n_edges_added=5 edges added
# n_edges_added=6 edges added
# n_edges_added=7 edges added
# n_edges_added=8 edges added
# n_edges_added=8 edges added
# n_edges_added=8 edges added
# n_edges_added=8 edges added
# n_edges_added=8 edges added
# n_edges_added=9 edges added
# n_edges_added=9 edges added
# n_edges_added=9 edges added
# n_edges_added=9 edges added
# n_edges_added=10 edges added
# n_edges_added=10 edges added
# n_edges_added=10 edges added
# n_edges_added=11 edges added
# n_edges_added=11 edges added
# n_edges_added=11 edges added
# n_edges_added=12 edges added
# n_edges_added=12 edges added
# n_edges_added=12 edges added
# n_edges_added=13 edges added
# n_edges_added=14 edges added
# n_edges_added=15 edges added
# n_edges_added=16 edges added
# n_edges_added=17 edges added
# n_edges_added=18 edges added
# n_edges_added=19 edges added
# n_edges_added=20 edges added
# n_edges_added=21 edges added
# n_edges_added=22 edges added
# n_edges_added=23 edges added
# n_edges_added=24 edges added
# n_edges_added=25 edges added
# n_edges_added=26 edges added
# n_edges_added=27 edges added
# n_edges_added=28 edges added
# n_edges_added=29 edges added
# n_edges_added=29 edges added
# n_edges_added=29 edges added
# n_edges_added=30 edges added
# n_edges_added=31 edges added
# n_edges_added=32 edges added
# n_edges_added=32 edges added
# n_edges_added=32 edges added
# n_edges_added=32 edges added
# n_edges_added=32 edges added
# n_edges_added=32 edges added
# n_edges_added=32 edges added
# n_edges_added=32 edges added
# n_edges_added=33 edges added
# n_edges_added=34 edges added
# n_edges_added=35 edges added
# n_edges_added=36 edges added
# n_edges_added=37 edges added
# n_edges_added=38 edges added
# n_edges_added=39 edges added
# n_edges_added=40 edges added
# n_edges_added=41 edges added
# n_edges_added=42 edges added
# n_edges_added=43 edges added
# n_edges_added=44 edges added
# n_edges_added=45 edges added
# n_edges_added=46 edges added
# n_edges_added=47 edges added
# n_edges_added=48 edges added
# n_edges_added=49 edges added
# n_edges_added=50 edges added
# n_edges_added=51 edges added
# n_edges_added=52 edges added
# n_edges_added=53 edges added
# n_edges_added=54 edges added
# n_edges_added=55 edges added
# n_edges_added=56 edges added
# n_edges_added=57 edges added
# n_edges_added=58 edges added
# n_edges_added=59 edges added
# n_edges_added=60 edges added
# n_edges_added=61 edges added
# n_edges_added=62 edges added
# n_edges_added=63 edges added
# n_edges_added=64 edges added
# n_edges_added=65 edges added
# n_edges_added=66 edges added
# n_edges_added=67 edges added
# n_edges_added=68 edges added
# n_edges_added=69 edges added
# n_edges_added=70 edges added
# n_edges_added=71 edges added
# n_edges_added=72 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=73 edges added
# n_edges_added=74 edges added
# n_edges_added=74 edges added
# n_edges_added=74 edges added
# n_edges_added=74 edges added
# n_edges_added=75 edges added
# n_edges_added=76 edges added
# n_edges_added=76 edges added
# n_edges_added=76 edges added
# n_edges_added=76 edges added
# n_edges_added=77 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=79 edges added
# n_edges_added=79 edges added
# n_edges_added=80 edges added
# n_edges_added=81 edges added
# n_edges_added=82 edges added
# n_edges_added=83 edges added
# n_edges_added=84 edges added
# n_edges_added=85 edges added
# n_edges_added=86 edges added
# n_edges_added=87 edges added
# n_edges_added=88 edges added
# n_edges_added=89 edges added
# n_edges_added=90 edges added
# n_edges_added=91 edges added
# n_edges_added=92 edges added
# n_edges_added=93 edges added
# n_edges_added=94 edges added
# n_edges_added=95 edges added
# n_edges_added=96 edges added
# n_edges_added=97 edges added
# n_edges_added=98 edges added
# n_edges_added=99 edges added
# n_edges_added=100 edges added
# 20 edges added to increase clustering
# 80 edges added based on uniform degree distribution

# %%
densify_fancy_05 = densify_fancy(network_pud, n_edges=500, target_degree_dist="uniform") # Approx 2 minutes
# Out:
# n_edges_added=1 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=2 edges added
# n_edges_added=3 edges added
# n_edges_added=4 edges added
# n_edges_added=5 edges added
# n_edges_added=6 edges added
# n_edges_added=7 edges added
# n_edges_added=8 edges added
# n_edges_added=9 edges added
# n_edges_added=10 edges added
# n_edges_added=11 edges added
# n_edges_added=12 edges added
# n_edges_added=13 edges added
# n_edges_added=13 edges added
# n_edges_added=13 edges added
# n_edges_added=13 edges added
# n_edges_added=13 edges added
# n_edges_added=14 edges added
# n_edges_added=15 edges added
# n_edges_added=16 edges added
# n_edges_added=17 edges added
# n_edges_added=18 edges added
# n_edges_added=18 edges added
# n_edges_added=18 edges added
# n_edges_added=18 edges added
# n_edges_added=19 edges added
# n_edges_added=20 edges added
# n_edges_added=21 edges added
# n_edges_added=21 edges added
# n_edges_added=22 edges added
# n_edges_added=23 edges added
# n_edges_added=24 edges added
# n_edges_added=24 edges added
# n_edges_added=24 edges added
# n_edges_added=25 edges added
# n_edges_added=25 edges added
# n_edges_added=25 edges added
# n_edges_added=25 edges added
# n_edges_added=26 edges added
# n_edges_added=27 edges added
# n_edges_added=28 edges added
# n_edges_added=29 edges added
# n_edges_added=30 edges added
# n_edges_added=31 edges added
# n_edges_added=32 edges added
# n_edges_added=33 edges added
# n_edges_added=34 edges added
# n_edges_added=35 edges added
# n_edges_added=36 edges added
# n_edges_added=36 edges added
# n_edges_added=36 edges added
# n_edges_added=36 edges added
# n_edges_added=36 edges added
# n_edges_added=37 edges added
# n_edges_added=38 edges added
# n_edges_added=38 edges added
# n_edges_added=38 edges added
# n_edges_added=38 edges added
# n_edges_added=38 edges added
# n_edges_added=38 edges added
# n_edges_added=38 edges added
# n_edges_added=39 edges added
# n_edges_added=40 edges added
# n_edges_added=40 edges added
# n_edges_added=40 edges added
# n_edges_added=41 edges added
# n_edges_added=42 edges added
# n_edges_added=43 edges added
# n_edges_added=44 edges added
# n_edges_added=45 edges added
# n_edges_added=46 edges added
# n_edges_added=47 edges added
# n_edges_added=48 edges added
# n_edges_added=49 edges added
# n_edges_added=50 edges added
# n_edges_added=51 edges added
# n_edges_added=52 edges added
# n_edges_added=53 edges added
# n_edges_added=54 edges added
# n_edges_added=54 edges added
# n_edges_added=54 edges added
# n_edges_added=54 edges added
# n_edges_added=54 edges added
# n_edges_added=55 edges added
# n_edges_added=55 edges added
# n_edges_added=55 edges added
# n_edges_added=55 edges added
# n_edges_added=55 edges added
# n_edges_added=56 edges added
# n_edges_added=56 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=57 edges added
# n_edges_added=58 edges added
# n_edges_added=58 edges added
# n_edges_added=59 edges added
# n_edges_added=60 edges added
# n_edges_added=61 edges added
# n_edges_added=62 edges added
# n_edges_added=63 edges added
# n_edges_added=64 edges added
# n_edges_added=65 edges added
# n_edges_added=66 edges added
# n_edges_added=66 edges added
# n_edges_added=66 edges added
# n_edges_added=66 edges added
# n_edges_added=66 edges added
# n_edges_added=66 edges added
# n_edges_added=67 edges added
# n_edges_added=68 edges added
# n_edges_added=69 edges added
# n_edges_added=70 edges added
# n_edges_added=71 edges added
# n_edges_added=72 edges added
# n_edges_added=73 edges added
# n_edges_added=74 edges added
# n_edges_added=75 edges added
# n_edges_added=75 edges added
# n_edges_added=75 edges added
# n_edges_added=75 edges added
# n_edges_added=76 edges added
# n_edges_added=76 edges added
# n_edges_added=77 edges added
# n_edges_added=77 edges added
# n_edges_added=77 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=78 edges added
# n_edges_added=79 edges added
# n_edges_added=79 edges added
# n_edges_added=80 edges added
# n_edges_added=81 edges added
# n_edges_added=82 edges added
# n_edges_added=83 edges added
# n_edges_added=84 edges added
# n_edges_added=85 edges added
# n_edges_added=86 edges added
# n_edges_added=87 edges added
# n_edges_added=87 edges added
# n_edges_added=87 edges added
# n_edges_added=87 edges added
# n_edges_added=87 edges added
# n_edges_added=88 edges added
# n_edges_added=89 edges added
# n_edges_added=90 edges added
# n_edges_added=91 edges added
# n_edges_added=92 edges added
# n_edges_added=93 edges added
# n_edges_added=94 edges added
# n_edges_added=94 edges added
# n_edges_added=94 edges added
# n_edges_added=94 edges added
# n_edges_added=94 edges added
# n_edges_added=94 edges added
# n_edges_added=94 edges added
# n_edges_added=95 edges added
# n_edges_added=96 edges added
# n_edges_added=97 edges added
# n_edges_added=98 edges added
# n_edges_added=99 edges added
# n_edges_added=100 edges added
# n_edges_added=101 edges added
# n_edges_added=102 edges added
# n_edges_added=103 edges added
# n_edges_added=104 edges added
# n_edges_added=105 edges added
# n_edges_added=106 edges added
# n_edges_added=107 edges added
# n_edges_added=108 edges added
# n_edges_added=109 edges added
# n_edges_added=110 edges added
# n_edges_added=111 edges added
# n_edges_added=112 edges added
# n_edges_added=113 edges added
# n_edges_added=114 edges added
# n_edges_added=115 edges added
# n_edges_added=116 edges added
# n_edges_added=117 edges added
# n_edges_added=118 edges added
# n_edges_added=119 edges added
# n_edges_added=120 edges added
# n_edges_added=121 edges added
# n_edges_added=122 edges added
# n_edges_added=123 edges added
# n_edges_added=124 edges added
# n_edges_added=125 edges added
# n_edges_added=126 edges added
# n_edges_added=127 edges added
# n_edges_added=128 edges added
# n_edges_added=129 edges added
# n_edges_added=130 edges added
# n_edges_added=131 edges added
# n_edges_added=132 edges added
# n_edges_added=133 edges added
# n_edges_added=134 edges added
# n_edges_added=135 edges added
# n_edges_added=136 edges added
# n_edges_added=137 edges added
# n_edges_added=138 edges added
# n_edges_added=139 edges added
# n_edges_added=140 edges added
# n_edges_added=141 edges added
# n_edges_added=141 edges added
# n_edges_added=141 edges added
# n_edges_added=141 edges added
# n_edges_added=141 edges added
# n_edges_added=142 edges added
# n_edges_added=143 edges added
# n_edges_added=144 edges added
# n_edges_added=145 edges added
# n_edges_added=146 edges added
# n_edges_added=147 edges added
# n_edges_added=148 edges added
# n_edges_added=148 edges added
# n_edges_added=148 edges added
# n_edges_added=149 edges added
# n_edges_added=150 edges added
# n_edges_added=151 edges added
# n_edges_added=152 edges added
# n_edges_added=153 edges added
# n_edges_added=154 edges added
# n_edges_added=155 edges added
# n_edges_added=156 edges added
# n_edges_added=157 edges added
# n_edges_added=158 edges added
# n_edges_added=158 edges added
# n_edges_added=158 edges added
# n_edges_added=158 edges added
# n_edges_added=158 edges added
# n_edges_added=159 edges added
# n_edges_added=160 edges added
# n_edges_added=160 edges added
# n_edges_added=161 edges added
# n_edges_added=161 edges added
# n_edges_added=161 edges added
# n_edges_added=161 edges added
# n_edges_added=161 edges added
# n_edges_added=162 edges added
# n_edges_added=163 edges added
# n_edges_added=164 edges added
# n_edges_added=164 edges added
# n_edges_added=164 edges added
# n_edges_added=165 edges added
# n_edges_added=166 edges added
# n_edges_added=167 edges added
# n_edges_added=168 edges added
# n_edges_added=169 edges added
# n_edges_added=170 edges added
# n_edges_added=171 edges added
# n_edges_added=172 edges added
# n_edges_added=172 edges added
# n_edges_added=172 edges added
# n_edges_added=172 edges added
# n_edges_added=172 edges added
# n_edges_added=173 edges added
# n_edges_added=173 edges added
# n_edges_added=173 edges added
# n_edges_added=173 edges added
# n_edges_added=173 edges added
# n_edges_added=173 edges added
# n_edges_added=174 edges added
# n_edges_added=175 edges added
# n_edges_added=175 edges added
# n_edges_added=175 edges added
# n_edges_added=175 edges added
# n_edges_added=175 edges added
# n_edges_added=176 edges added
# n_edges_added=177 edges added
# n_edges_added=178 edges added
# n_edges_added=179 edges added
# n_edges_added=180 edges added
# n_edges_added=181 edges added
# n_edges_added=182 edges added
# n_edges_added=183 edges added
# n_edges_added=183 edges added
# n_edges_added=183 edges added
# n_edges_added=184 edges added
# n_edges_added=185 edges added
# n_edges_added=185 edges added
# n_edges_added=185 edges added
# n_edges_added=185 edges added
# n_edges_added=185 edges added
# n_edges_added=185 edges added
# n_edges_added=185 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=186 edges added
# n_edges_added=187 edges added
# n_edges_added=187 edges added
# n_edges_added=187 edges added
# n_edges_added=187 edges added
# n_edges_added=187 edges added
# n_edges_added=187 edges added
# n_edges_added=188 edges added
# n_edges_added=188 edges added
# n_edges_added=188 edges added
# n_edges_added=188 edges added
# n_edges_added=188 edges added
# n_edges_added=188 edges added
# n_edges_added=189 edges added
# n_edges_added=190 edges added
# n_edges_added=191 edges added
# n_edges_added=192 edges added
# n_edges_added=193 edges added
# n_edges_added=194 edges added
# n_edges_added=195 edges added
# n_edges_added=196 edges added
# n_edges_added=197 edges added
# n_edges_added=198 edges added
# n_edges_added=199 edges added
# n_edges_added=200 edges added
# n_edges_added=201 edges added
# n_edges_added=202 edges added
# n_edges_added=203 edges added
# n_edges_added=204 edges added
# n_edges_added=204 edges added
# n_edges_added=204 edges added
# n_edges_added=204 edges added
# n_edges_added=205 edges added
# n_edges_added=206 edges added
# n_edges_added=206 edges added
# n_edges_added=206 edges added
# n_edges_added=206 edges added
# n_edges_added=206 edges added
# n_edges_added=206 edges added
# n_edges_added=206 edges added
# n_edges_added=207 edges added
# n_edges_added=207 edges added
# n_edges_added=207 edges added
# n_edges_added=207 edges added
# n_edges_added=208 edges added
# n_edges_added=208 edges added
# n_edges_added=208 edges added
# n_edges_added=208 edges added
# n_edges_added=208 edges added
# n_edges_added=209 edges added
# n_edges_added=209 edges added
# n_edges_added=210 edges added
# n_edges_added=211 edges added
# n_edges_added=211 edges added
# n_edges_added=211 edges added
# n_edges_added=211 edges added
# n_edges_added=211 edges added
# n_edges_added=211 edges added
# n_edges_added=211 edges added
# n_edges_added=212 edges added
# n_edges_added=212 edges added
# n_edges_added=212 edges added
# n_edges_added=213 edges added
# n_edges_added=214 edges added
# n_edges_added=215 edges added
# n_edges_added=216 edges added
# n_edges_added=217 edges added
# n_edges_added=218 edges added
# n_edges_added=219 edges added
# n_edges_added=220 edges added
# n_edges_added=221 edges added
# n_edges_added=222 edges added
# n_edges_added=223 edges added
# n_edges_added=224 edges added
# n_edges_added=225 edges added
# n_edges_added=226 edges added
# n_edges_added=227 edges added
# n_edges_added=227 edges added
# n_edges_added=227 edges added
# n_edges_added=227 edges added
# n_edges_added=227 edges added
# n_edges_added=228 edges added
# n_edges_added=228 edges added
# n_edges_added=228 edges added
# n_edges_added=228 edges added
# n_edges_added=228 edges added
# n_edges_added=228 edges added
# n_edges_added=228 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=230 edges added
# n_edges_added=231 edges added
# n_edges_added=232 edges added
# n_edges_added=233 edges added
# n_edges_added=234 edges added
# n_edges_added=235 edges added
# n_edges_added=236 edges added
# n_edges_added=236 edges added
# n_edges_added=236 edges added
# n_edges_added=237 edges added
# n_edges_added=237 edges added
# n_edges_added=238 edges added
# n_edges_added=238 edges added
# n_edges_added=238 edges added
# n_edges_added=238 edges added
# n_edges_added=238 edges added
# n_edges_added=238 edges added
# n_edges_added=239 edges added
# n_edges_added=240 edges added
# n_edges_added=241 edges added
# n_edges_added=242 edges added
# n_edges_added=243 edges added
# n_edges_added=243 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=245 edges added
# n_edges_added=246 edges added
# n_edges_added=247 edges added
# n_edges_added=248 edges added
# n_edges_added=248 edges added
# n_edges_added=248 edges added
# n_edges_added=249 edges added
# n_edges_added=250 edges added
# n_edges_added=251 edges added
# n_edges_added=252 edges added
# n_edges_added=253 edges added
# n_edges_added=254 edges added
# n_edges_added=254 edges added
# n_edges_added=254 edges added
# n_edges_added=254 edges added
# n_edges_added=254 edges added
# n_edges_added=254 edges added
# n_edges_added=255 edges added
# n_edges_added=256 edges added
# n_edges_added=257 edges added
# n_edges_added=258 edges added
# n_edges_added=259 edges added
# n_edges_added=260 edges added
# n_edges_added=261 edges added
# n_edges_added=261 edges added
# n_edges_added=261 edges added
# n_edges_added=262 edges added
# n_edges_added=263 edges added
# n_edges_added=263 edges added
# n_edges_added=263 edges added
# n_edges_added=263 edges added
# n_edges_added=263 edges added
# n_edges_added=264 edges added
# n_edges_added=265 edges added
# n_edges_added=266 edges added
# n_edges_added=267 edges added
# n_edges_added=268 edges added
# n_edges_added=269 edges added
# n_edges_added=270 edges added
# n_edges_added=270 edges added
# n_edges_added=270 edges added
# n_edges_added=270 edges added
# n_edges_added=271 edges added
# n_edges_added=271 edges added
# n_edges_added=272 edges added
# n_edges_added=272 edges added
# n_edges_added=272 edges added
# n_edges_added=272 edges added
# n_edges_added=272 edges added
# n_edges_added=272 edges added
# n_edges_added=272 edges added
# n_edges_added=273 edges added
# n_edges_added=273 edges added
# n_edges_added=273 edges added
# n_edges_added=273 edges added
# n_edges_added=273 edges added
# n_edges_added=273 edges added
# n_edges_added=273 edges added
# n_edges_added=273 edges added
# n_edges_added=274 edges added
# n_edges_added=275 edges added
# n_edges_added=276 edges added
# n_edges_added=277 edges added
# n_edges_added=278 edges added
# n_edges_added=279 edges added
# n_edges_added=280 edges added
# n_edges_added=281 edges added
# n_edges_added=282 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=283 edges added
# n_edges_added=284 edges added
# n_edges_added=284 edges added
# n_edges_added=285 edges added
# n_edges_added=285 edges added
# n_edges_added=286 edges added
# n_edges_added=287 edges added
# n_edges_added=287 edges added
# n_edges_added=287 edges added
# n_edges_added=287 edges added
# n_edges_added=287 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=288 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=289 edges added
# n_edges_added=290 edges added
# n_edges_added=291 edges added
# n_edges_added=291 edges added
# n_edges_added=291 edges added
# n_edges_added=291 edges added
# n_edges_added=292 edges added
# n_edges_added=293 edges added
# n_edges_added=294 edges added
# n_edges_added=295 edges added
# n_edges_added=296 edges added
# n_edges_added=297 edges added
# n_edges_added=298 edges added
# n_edges_added=299 edges added
# n_edges_added=300 edges added
# n_edges_added=301 edges added
# n_edges_added=302 edges added
# n_edges_added=303 edges added
# n_edges_added=304 edges added
# n_edges_added=305 edges added
# n_edges_added=305 edges added
# n_edges_added=305 edges added
# n_edges_added=305 edges added
# n_edges_added=305 edges added
# n_edges_added=305 edges added
# n_edges_added=305 edges added
# n_edges_added=305 edges added
# n_edges_added=306 edges added
# n_edges_added=307 edges added
# n_edges_added=307 edges added
# n_edges_added=308 edges added
# n_edges_added=309 edges added
# n_edges_added=310 edges added
# n_edges_added=310 edges added
# n_edges_added=310 edges added
# n_edges_added=310 edges added
# n_edges_added=310 edges added
# n_edges_added=310 edges added
# n_edges_added=311 edges added
# n_edges_added=311 edges added
# n_edges_added=312 edges added
# n_edges_added=313 edges added
# n_edges_added=313 edges added
# n_edges_added=313 edges added
# n_edges_added=313 edges added
# n_edges_added=313 edges added
# n_edges_added=314 edges added
# n_edges_added=314 edges added
# n_edges_added=315 edges added
# n_edges_added=316 edges added
# n_edges_added=317 edges added
# n_edges_added=318 edges added
# n_edges_added=318 edges added
# n_edges_added=318 edges added
# n_edges_added=319 edges added
# n_edges_added=319 edges added
# n_edges_added=319 edges added
# n_edges_added=319 edges added
# n_edges_added=319 edges added
# n_edges_added=320 edges added
# n_edges_added=321 edges added
# n_edges_added=322 edges added
# n_edges_added=323 edges added
# n_edges_added=324 edges added
# n_edges_added=325 edges added
# n_edges_added=326 edges added
# n_edges_added=327 edges added
# n_edges_added=328 edges added
# n_edges_added=329 edges added
# n_edges_added=330 edges added
# n_edges_added=331 edges added
# n_edges_added=332 edges added
# n_edges_added=333 edges added
# n_edges_added=334 edges added
# n_edges_added=335 edges added
# n_edges_added=336 edges added
# n_edges_added=337 edges added
# n_edges_added=338 edges added
# n_edges_added=339 edges added
# n_edges_added=340 edges added
# n_edges_added=341 edges added
# n_edges_added=341 edges added
# n_edges_added=341 edges added
# n_edges_added=341 edges added
# n_edges_added=342 edges added
# n_edges_added=343 edges added
# n_edges_added=343 edges added
# n_edges_added=343 edges added
# n_edges_added=343 edges added
# n_edges_added=343 edges added
# n_edges_added=343 edges added
# n_edges_added=343 edges added
# n_edges_added=344 edges added
# n_edges_added=345 edges added
# n_edges_added=346 edges added
# n_edges_added=347 edges added
# n_edges_added=348 edges added
# n_edges_added=348 edges added
# n_edges_added=348 edges added
# n_edges_added=348 edges added
# n_edges_added=348 edges added
# n_edges_added=348 edges added
# n_edges_added=348 edges added
# n_edges_added=348 edges added
# n_edges_added=349 edges added
# n_edges_added=350 edges added
# n_edges_added=351 edges added
# n_edges_added=352 edges added
# n_edges_added=352 edges added
# n_edges_added=353 edges added
# n_edges_added=353 edges added
# n_edges_added=353 edges added
# n_edges_added=354 edges added
# n_edges_added=355 edges added
# n_edges_added=356 edges added
# n_edges_added=357 edges added
# n_edges_added=358 edges added
# n_edges_added=358 edges added
# n_edges_added=358 edges added
# n_edges_added=358 edges added
# n_edges_added=359 edges added
# n_edges_added=359 edges added
# n_edges_added=360 edges added
# n_edges_added=361 edges added
# n_edges_added=362 edges added
# n_edges_added=363 edges added
# n_edges_added=364 edges added
# n_edges_added=365 edges added
# n_edges_added=365 edges added
# n_edges_added=366 edges added
# n_edges_added=366 edges added
# n_edges_added=366 edges added
# n_edges_added=366 edges added
# n_edges_added=366 edges added
# n_edges_added=367 edges added
# n_edges_added=368 edges added
# n_edges_added=369 edges added
# n_edges_added=370 edges added
# n_edges_added=371 edges added
# n_edges_added=372 edges added
# n_edges_added=373 edges added
# n_edges_added=374 edges added
# n_edges_added=375 edges added
# n_edges_added=376 edges added
# n_edges_added=377 edges added
# n_edges_added=378 edges added
# n_edges_added=379 edges added
# n_edges_added=380 edges added
# n_edges_added=381 edges added
# n_edges_added=382 edges added
# n_edges_added=383 edges added
# n_edges_added=384 edges added
# n_edges_added=385 edges added
# n_edges_added=386 edges added
# n_edges_added=387 edges added
# n_edges_added=388 edges added
# n_edges_added=388 edges added
# n_edges_added=389 edges added
# n_edges_added=390 edges added
# n_edges_added=391 edges added
# n_edges_added=392 edges added
# n_edges_added=393 edges added
# n_edges_added=394 edges added
# n_edges_added=395 edges added
# n_edges_added=396 edges added
# n_edges_added=397 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=398 edges added
# n_edges_added=399 edges added
# n_edges_added=400 edges added
# n_edges_added=401 edges added
# n_edges_added=401 edges added
# n_edges_added=401 edges added
# n_edges_added=401 edges added
# n_edges_added=401 edges added
# n_edges_added=401 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=402 edges added
# n_edges_added=403 edges added
# n_edges_added=403 edges added
# n_edges_added=403 edges added
# n_edges_added=403 edges added
# n_edges_added=403 edges added
# n_edges_added=403 edges added
# n_edges_added=403 edges added
# n_edges_added=404 edges added
# n_edges_added=405 edges added
# n_edges_added=406 edges added
# n_edges_added=407 edges added
# n_edges_added=408 edges added
# n_edges_added=409 edges added
# n_edges_added=410 edges added
# n_edges_added=411 edges added
# n_edges_added=412 edges added
# n_edges_added=413 edges added
# n_edges_added=414 edges added
# n_edges_added=415 edges added
# n_edges_added=415 edges added
# n_edges_added=415 edges added
# n_edges_added=415 edges added
# n_edges_added=416 edges added
# n_edges_added=417 edges added
# n_edges_added=418 edges added
# n_edges_added=419 edges added
# n_edges_added=420 edges added
# n_edges_added=421 edges added
# n_edges_added=421 edges added
# n_edges_added=422 edges added
# n_edges_added=423 edges added
# n_edges_added=423 edges added
# n_edges_added=423 edges added
# n_edges_added=423 edges added
# n_edges_added=424 edges added
# n_edges_added=424 edges added
# n_edges_added=424 edges added
# n_edges_added=424 edges added
# n_edges_added=424 edges added
# n_edges_added=425 edges added
# n_edges_added=426 edges added
# n_edges_added=426 edges added
# n_edges_added=426 edges added
# n_edges_added=426 edges added
# n_edges_added=427 edges added
# n_edges_added=428 edges added
# n_edges_added=429 edges added
# n_edges_added=430 edges added
# n_edges_added=431 edges added
# n_edges_added=431 edges added
# n_edges_added=432 edges added
# n_edges_added=433 edges added
# n_edges_added=434 edges added
# n_edges_added=434 edges added
# n_edges_added=434 edges added
# n_edges_added=434 edges added
# n_edges_added=434 edges added
# n_edges_added=434 edges added
# n_edges_added=434 edges added
# n_edges_added=434 edges added
# n_edges_added=435 edges added
# n_edges_added=436 edges added
# n_edges_added=437 edges added
# n_edges_added=438 edges added
# n_edges_added=439 edges added
# n_edges_added=440 edges added
# n_edges_added=441 edges added
# n_edges_added=442 edges added
# n_edges_added=443 edges added
# n_edges_added=444 edges added
# n_edges_added=445 edges added
# n_edges_added=446 edges added
# n_edges_added=447 edges added
# n_edges_added=447 edges added
# n_edges_added=448 edges added
# n_edges_added=449 edges added
# n_edges_added=450 edges added
# n_edges_added=451 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=453 edges added
# n_edges_added=453 edges added
# n_edges_added=453 edges added
# n_edges_added=454 edges added
# n_edges_added=454 edges added
# n_edges_added=455 edges added
# n_edges_added=455 edges added
# n_edges_added=455 edges added
# n_edges_added=455 edges added
# n_edges_added=455 edges added
# n_edges_added=455 edges added
# n_edges_added=456 edges added
# n_edges_added=457 edges added
# n_edges_added=457 edges added
# n_edges_added=458 edges added
# n_edges_added=459 edges added
# n_edges_added=460 edges added
# n_edges_added=460 edges added
# n_edges_added=460 edges added
# n_edges_added=461 edges added
# n_edges_added=462 edges added
# n_edges_added=463 edges added
# n_edges_added=464 edges added
# n_edges_added=465 edges added
# n_edges_added=466 edges added
# n_edges_added=467 edges added
# n_edges_added=468 edges added
# n_edges_added=469 edges added
# n_edges_added=469 edges added
# n_edges_added=470 edges added
# n_edges_added=470 edges added
# n_edges_added=470 edges added
# n_edges_added=471 edges added
# n_edges_added=472 edges added
# n_edges_added=473 edges added
# n_edges_added=474 edges added
# n_edges_added=475 edges added
# n_edges_added=476 edges added
# n_edges_added=477 edges added
# n_edges_added=478 edges added
# n_edges_added=479 edges added
# n_edges_added=480 edges added
# n_edges_added=481 edges added
# n_edges_added=481 edges added
# n_edges_added=482 edges added
# n_edges_added=483 edges added
# n_edges_added=484 edges added
# n_edges_added=484 edges added
# n_edges_added=485 edges added
# n_edges_added=486 edges added
# n_edges_added=487 edges added
# n_edges_added=488 edges added
# n_edges_added=489 edges added
# n_edges_added=490 edges added
# n_edges_added=491 edges added
# n_edges_added=492 edges added
# n_edges_added=493 edges added
# n_edges_added=494 edges added
# n_edges_added=495 edges added
# n_edges_added=495 edges added
# n_edges_added=496 edges added
# n_edges_added=496 edges added
# n_edges_added=496 edges added
# n_edges_added=496 edges added
# n_edges_added=496 edges added
# n_edges_added=497 edges added
# n_edges_added=498 edges added
# n_edges_added=499 edges added
# n_edges_added=500 edges added
# 137 edges added to increase clustering
# 363 edges added based on uniform degree distribution

# %%
densify_fancy_1 = densify_fancy(network_pud, n_edges=1000, target_degree_dist="uniform") # Approx 4:15 minutes
# Out:
# n_edges_added=1 edges added
# n_edges_added=1 edges added
# n_edges_added=1 edges added
# n_edges_added=1 edges added
# n_edges_added=1 edges added
# n_edges_added=2 edges added
# n_edges_added=3 edges added
# n_edges_added=4 edges added
# n_edges_added=5 edges added
# n_edges_added=6 edges added
# n_edges_added=7 edges added
# n_edges_added=8 edges added
# n_edges_added=9 edges added
# n_edges_added=10 edges added
# n_edges_added=10 edges added
# n_edges_added=10 edges added
# n_edges_added=10 edges added
# n_edges_added=10 edges added
# n_edges_added=10 edges added
# n_edges_added=11 edges added
# n_edges_added=11 edges added
# n_edges_added=12 edges added
# n_edges_added=13 edges added
# n_edges_added=14 edges added
# n_edges_added=15 edges added
# n_edges_added=16 edges added
# n_edges_added=17 edges added
# n_edges_added=18 edges added
# n_edges_added=19 edges added
# n_edges_added=20 edges added
# n_edges_added=21 edges added
# n_edges_added=22 edges added
# n_edges_added=23 edges added
# n_edges_added=23 edges added
# n_edges_added=23 edges added
# n_edges_added=23 edges added
# n_edges_added=23 edges added
# n_edges_added=24 edges added
# n_edges_added=24 edges added
# n_edges_added=24 edges added
# n_edges_added=24 edges added
# n_edges_added=24 edges added
# n_edges_added=25 edges added
# n_edges_added=25 edges added
# n_edges_added=26 edges added
# n_edges_added=27 edges added
# n_edges_added=28 edges added
# n_edges_added=29 edges added
# n_edges_added=30 edges added
# n_edges_added=31 edges added
# n_edges_added=31 edges added
# n_edges_added=32 edges added
# n_edges_added=33 edges added
# n_edges_added=34 edges added
# n_edges_added=35 edges added
# n_edges_added=36 edges added
# n_edges_added=37 edges added
# n_edges_added=38 edges added
# n_edges_added=39 edges added
# n_edges_added=40 edges added
# n_edges_added=41 edges added
# n_edges_added=42 edges added
# n_edges_added=42 edges added
# n_edges_added=42 edges added
# n_edges_added=42 edges added
# n_edges_added=42 edges added
# n_edges_added=42 edges added
# n_edges_added=42 edges added
# n_edges_added=42 edges added
# n_edges_added=43 edges added
# n_edges_added=44 edges added
# n_edges_added=45 edges added
# n_edges_added=45 edges added
# n_edges_added=45 edges added
# n_edges_added=46 edges added
# n_edges_added=47 edges added
# n_edges_added=48 edges added
# n_edges_added=49 edges added
# n_edges_added=50 edges added
# n_edges_added=51 edges added
# n_edges_added=52 edges added
# n_edges_added=53 edges added
# n_edges_added=54 edges added
# n_edges_added=55 edges added
# n_edges_added=56 edges added
# n_edges_added=57 edges added
# n_edges_added=58 edges added
# n_edges_added=59 edges added
# n_edges_added=60 edges added
# n_edges_added=61 edges added
# n_edges_added=62 edges added
# n_edges_added=62 edges added
# n_edges_added=62 edges added
# n_edges_added=62 edges added
# n_edges_added=62 edges added
# n_edges_added=63 edges added
# n_edges_added=64 edges added
# n_edges_added=65 edges added
# n_edges_added=66 edges added
# n_edges_added=67 edges added
# n_edges_added=68 edges added
# n_edges_added=69 edges added
# n_edges_added=70 edges added
# n_edges_added=71 edges added
# n_edges_added=72 edges added
# n_edges_added=73 edges added
# n_edges_added=74 edges added
# n_edges_added=75 edges added
# n_edges_added=76 edges added
# n_edges_added=77 edges added
# n_edges_added=78 edges added
# n_edges_added=79 edges added
# n_edges_added=80 edges added
# n_edges_added=81 edges added
# n_edges_added=82 edges added
# n_edges_added=83 edges added
# n_edges_added=84 edges added
# n_edges_added=85 edges added
# n_edges_added=86 edges added
# n_edges_added=87 edges added
# n_edges_added=88 edges added
# n_edges_added=89 edges added
# n_edges_added=90 edges added
# n_edges_added=91 edges added
# n_edges_added=92 edges added
# n_edges_added=93 edges added
# n_edges_added=94 edges added
# n_edges_added=94 edges added
# n_edges_added=95 edges added
# n_edges_added=95 edges added
# n_edges_added=95 edges added
# n_edges_added=95 edges added
# n_edges_added=95 edges added
# n_edges_added=96 edges added
# n_edges_added=97 edges added
# n_edges_added=98 edges added
# n_edges_added=99 edges added
# n_edges_added=100 edges added
# n_edges_added=100 edges added
# n_edges_added=101 edges added
# n_edges_added=101 edges added
# n_edges_added=102 edges added
# n_edges_added=103 edges added
# n_edges_added=104 edges added
# n_edges_added=105 edges added
# n_edges_added=106 edges added
# n_edges_added=107 edges added
# n_edges_added=107 edges added
# n_edges_added=107 edges added
# n_edges_added=107 edges added
# n_edges_added=108 edges added
# n_edges_added=109 edges added
# n_edges_added=109 edges added
# n_edges_added=109 edges added
# n_edges_added=109 edges added
# n_edges_added=109 edges added
# n_edges_added=110 edges added
# n_edges_added=111 edges added
# n_edges_added=112 edges added
# n_edges_added=113 edges added
# n_edges_added=114 edges added
# n_edges_added=115 edges added
# n_edges_added=116 edges added
# n_edges_added=117 edges added
# n_edges_added=118 edges added
# n_edges_added=119 edges added
# n_edges_added=120 edges added
# n_edges_added=121 edges added
# n_edges_added=122 edges added
# n_edges_added=123 edges added
# n_edges_added=124 edges added
# n_edges_added=125 edges added
# n_edges_added=126 edges added
# n_edges_added=127 edges added
# n_edges_added=128 edges added
# n_edges_added=128 edges added
# n_edges_added=128 edges added
# n_edges_added=129 edges added
# n_edges_added=130 edges added
# n_edges_added=131 edges added
# n_edges_added=132 edges added
# n_edges_added=132 edges added
# n_edges_added=132 edges added
# n_edges_added=132 edges added
# n_edges_added=133 edges added
# n_edges_added=134 edges added
# n_edges_added=135 edges added
# n_edges_added=136 edges added
# n_edges_added=137 edges added
# n_edges_added=138 edges added
# n_edges_added=139 edges added
# n_edges_added=140 edges added
# n_edges_added=141 edges added
# n_edges_added=142 edges added
# n_edges_added=143 edges added
# n_edges_added=144 edges added
# n_edges_added=145 edges added
# n_edges_added=146 edges added
# n_edges_added=147 edges added
# n_edges_added=147 edges added
# n_edges_added=148 edges added
# n_edges_added=149 edges added
# n_edges_added=150 edges added
# n_edges_added=151 edges added
# n_edges_added=152 edges added
# n_edges_added=153 edges added
# n_edges_added=154 edges added
# n_edges_added=155 edges added
# n_edges_added=156 edges added
# n_edges_added=157 edges added
# n_edges_added=158 edges added
# n_edges_added=159 edges added
# n_edges_added=160 edges added
# n_edges_added=161 edges added
# n_edges_added=162 edges added
# n_edges_added=163 edges added
# n_edges_added=164 edges added
# n_edges_added=165 edges added
# n_edges_added=166 edges added
# n_edges_added=167 edges added
# n_edges_added=168 edges added
# n_edges_added=169 edges added
# n_edges_added=170 edges added
# n_edges_added=171 edges added
# n_edges_added=172 edges added
# n_edges_added=173 edges added
# n_edges_added=174 edges added
# n_edges_added=175 edges added
# n_edges_added=176 edges added
# n_edges_added=177 edges added
# n_edges_added=178 edges added
# n_edges_added=179 edges added
# n_edges_added=180 edges added
# n_edges_added=181 edges added
# n_edges_added=182 edges added
# n_edges_added=183 edges added
# n_edges_added=184 edges added
# n_edges_added=185 edges added
# n_edges_added=186 edges added
# n_edges_added=187 edges added
# n_edges_added=188 edges added
# n_edges_added=189 edges added
# n_edges_added=190 edges added
# n_edges_added=191 edges added
# n_edges_added=192 edges added
# n_edges_added=192 edges added
# n_edges_added=192 edges added
# n_edges_added=193 edges added
# n_edges_added=194 edges added
# n_edges_added=195 edges added
# n_edges_added=196 edges added
# n_edges_added=197 edges added
# n_edges_added=198 edges added
# n_edges_added=199 edges added
# n_edges_added=200 edges added
# n_edges_added=201 edges added
# n_edges_added=202 edges added
# n_edges_added=203 edges added
# n_edges_added=204 edges added
# n_edges_added=205 edges added
# n_edges_added=206 edges added
# n_edges_added=207 edges added
# n_edges_added=208 edges added
# n_edges_added=209 edges added
# n_edges_added=210 edges added
# n_edges_added=211 edges added
# n_edges_added=212 edges added
# n_edges_added=213 edges added
# n_edges_added=213 edges added
# n_edges_added=213 edges added
# n_edges_added=213 edges added
# n_edges_added=213 edges added
# n_edges_added=213 edges added
# n_edges_added=213 edges added
# n_edges_added=213 edges added
# n_edges_added=214 edges added
# n_edges_added=215 edges added
# n_edges_added=216 edges added
# n_edges_added=217 edges added
# n_edges_added=218 edges added
# n_edges_added=219 edges added
# n_edges_added=219 edges added
# n_edges_added=220 edges added
# n_edges_added=221 edges added
# n_edges_added=222 edges added
# n_edges_added=223 edges added
# n_edges_added=224 edges added
# n_edges_added=225 edges added
# n_edges_added=226 edges added
# n_edges_added=227 edges added
# n_edges_added=228 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=229 edges added
# n_edges_added=230 edges added
# n_edges_added=230 edges added
# n_edges_added=231 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=232 edges added
# n_edges_added=233 edges added
# n_edges_added=233 edges added
# n_edges_added=233 edges added
# n_edges_added=233 edges added
# n_edges_added=234 edges added
# n_edges_added=235 edges added
# n_edges_added=236 edges added
# n_edges_added=237 edges added
# n_edges_added=238 edges added
# n_edges_added=239 edges added
# n_edges_added=240 edges added
# n_edges_added=241 edges added
# n_edges_added=242 edges added
# n_edges_added=243 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=244 edges added
# n_edges_added=245 edges added
# n_edges_added=246 edges added
# n_edges_added=247 edges added
# n_edges_added=248 edges added
# n_edges_added=249 edges added
# n_edges_added=250 edges added
# n_edges_added=251 edges added
# n_edges_added=252 edges added
# n_edges_added=253 edges added
# n_edges_added=254 edges added
# n_edges_added=255 edges added
# n_edges_added=256 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=257 edges added
# n_edges_added=258 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=259 edges added
# n_edges_added=260 edges added
# n_edges_added=260 edges added
# n_edges_added=261 edges added
# n_edges_added=261 edges added
# n_edges_added=261 edges added
# n_edges_added=261 edges added
# n_edges_added=262 edges added
# n_edges_added=263 edges added
# n_edges_added=264 edges added
# n_edges_added=265 edges added
# n_edges_added=266 edges added
# n_edges_added=267 edges added
# n_edges_added=268 edges added
# n_edges_added=269 edges added
# n_edges_added=270 edges added
# n_edges_added=271 edges added
# n_edges_added=272 edges added
# n_edges_added=273 edges added
# n_edges_added=274 edges added
# n_edges_added=274 edges added
# n_edges_added=274 edges added
# n_edges_added=274 edges added
# n_edges_added=275 edges added
# n_edges_added=275 edges added
# n_edges_added=275 edges added
# n_edges_added=275 edges added
# n_edges_added=275 edges added
# n_edges_added=275 edges added
# n_edges_added=275 edges added
# n_edges_added=275 edges added
# n_edges_added=276 edges added
# n_edges_added=276 edges added
# n_edges_added=276 edges added
# n_edges_added=276 edges added
# n_edges_added=276 edges added
# n_edges_added=276 edges added
# n_edges_added=276 edges added
# n_edges_added=276 edges added
# n_edges_added=277 edges added
# n_edges_added=278 edges added
# n_edges_added=279 edges added
# n_edges_added=280 edges added
# n_edges_added=281 edges added
# n_edges_added=282 edges added
# n_edges_added=283 edges added
# n_edges_added=284 edges added
# n_edges_added=285 edges added
# n_edges_added=286 edges added
# n_edges_added=287 edges added
# n_edges_added=288 edges added
# n_edges_added=289 edges added
# n_edges_added=290 edges added
# n_edges_added=291 edges added
# n_edges_added=292 edges added
# n_edges_added=293 edges added
# n_edges_added=293 edges added
# n_edges_added=294 edges added
# n_edges_added=295 edges added
# n_edges_added=296 edges added
# n_edges_added=297 edges added
# n_edges_added=298 edges added
# n_edges_added=298 edges added
# n_edges_added=298 edges added
# n_edges_added=298 edges added
# n_edges_added=298 edges added
# n_edges_added=298 edges added
# n_edges_added=299 edges added
# n_edges_added=299 edges added
# n_edges_added=299 edges added
# n_edges_added=299 edges added
# n_edges_added=299 edges added
# n_edges_added=300 edges added
# n_edges_added=301 edges added
# n_edges_added=301 edges added
# n_edges_added=301 edges added
# n_edges_added=301 edges added
# n_edges_added=301 edges added
# n_edges_added=302 edges added
# n_edges_added=302 edges added
# n_edges_added=302 edges added
# n_edges_added=302 edges added
# n_edges_added=302 edges added
# n_edges_added=303 edges added
# n_edges_added=303 edges added
# n_edges_added=303 edges added
# n_edges_added=303 edges added
# n_edges_added=303 edges added
# n_edges_added=303 edges added
# n_edges_added=303 edges added
# n_edges_added=303 edges added
# n_edges_added=304 edges added
# n_edges_added=305 edges added
# n_edges_added=306 edges added
# n_edges_added=307 edges added
# n_edges_added=308 edges added
# n_edges_added=309 edges added
# n_edges_added=310 edges added
# n_edges_added=311 edges added
# n_edges_added=312 edges added
# n_edges_added=313 edges added
# n_edges_added=314 edges added
# n_edges_added=315 edges added
# n_edges_added=316 edges added
# n_edges_added=317 edges added
# n_edges_added=318 edges added
# n_edges_added=319 edges added
# n_edges_added=320 edges added
# n_edges_added=321 edges added
# n_edges_added=322 edges added
# n_edges_added=323 edges added
# n_edges_added=324 edges added
# n_edges_added=324 edges added
# n_edges_added=324 edges added
# n_edges_added=324 edges added
# n_edges_added=324 edges added
# n_edges_added=325 edges added
# n_edges_added=326 edges added
# n_edges_added=327 edges added
# n_edges_added=328 edges added
# n_edges_added=329 edges added
# n_edges_added=330 edges added
# n_edges_added=331 edges added
# n_edges_added=332 edges added
# n_edges_added=333 edges added
# n_edges_added=334 edges added
# n_edges_added=335 edges added
# n_edges_added=336 edges added
# n_edges_added=337 edges added
# n_edges_added=337 edges added
# n_edges_added=338 edges added
# n_edges_added=338 edges added
# n_edges_added=339 edges added
# n_edges_added=339 edges added
# n_edges_added=339 edges added
# n_edges_added=339 edges added
# n_edges_added=339 edges added
# n_edges_added=339 edges added
# n_edges_added=340 edges added
# n_edges_added=341 edges added
# n_edges_added=342 edges added
# n_edges_added=343 edges added
# n_edges_added=344 edges added
# n_edges_added=345 edges added
# n_edges_added=346 edges added
# n_edges_added=347 edges added
# n_edges_added=348 edges added
# n_edges_added=349 edges added
# n_edges_added=350 edges added
# n_edges_added=350 edges added
# n_edges_added=350 edges added
# n_edges_added=350 edges added
# n_edges_added=350 edges added
# n_edges_added=350 edges added
# n_edges_added=350 edges added
# n_edges_added=351 edges added
# n_edges_added=352 edges added
# n_edges_added=353 edges added
# n_edges_added=353 edges added
# n_edges_added=353 edges added
# n_edges_added=354 edges added
# n_edges_added=355 edges added
# n_edges_added=356 edges added
# n_edges_added=357 edges added
# n_edges_added=358 edges added
# n_edges_added=358 edges added
# n_edges_added=358 edges added
# n_edges_added=359 edges added
# n_edges_added=359 edges added
# n_edges_added=359 edges added
# n_edges_added=360 edges added
# n_edges_added=360 edges added
# n_edges_added=360 edges added
# n_edges_added=360 edges added
# n_edges_added=360 edges added
# n_edges_added=360 edges added
# n_edges_added=360 edges added
# n_edges_added=361 edges added
# n_edges_added=362 edges added
# n_edges_added=363 edges added
# n_edges_added=363 edges added
# n_edges_added=363 edges added
# n_edges_added=364 edges added
# n_edges_added=365 edges added
# n_edges_added=366 edges added
# n_edges_added=367 edges added
# n_edges_added=367 edges added
# n_edges_added=367 edges added
# n_edges_added=367 edges added
# n_edges_added=367 edges added
# n_edges_added=368 edges added
# n_edges_added=368 edges added
# n_edges_added=368 edges added
# n_edges_added=368 edges added
# n_edges_added=368 edges added
# n_edges_added=369 edges added
# n_edges_added=369 edges added
# n_edges_added=370 edges added
# n_edges_added=371 edges added
# n_edges_added=371 edges added
# n_edges_added=371 edges added
# n_edges_added=371 edges added
# n_edges_added=372 edges added
# n_edges_added=372 edges added
# n_edges_added=372 edges added
# n_edges_added=372 edges added
# n_edges_added=373 edges added
# n_edges_added=374 edges added
# n_edges_added=375 edges added
# n_edges_added=376 edges added
# n_edges_added=377 edges added
# n_edges_added=378 edges added
# n_edges_added=378 edges added
# n_edges_added=379 edges added
# n_edges_added=379 edges added
# n_edges_added=379 edges added
# n_edges_added=380 edges added
# n_edges_added=381 edges added
# n_edges_added=382 edges added
# n_edges_added=383 edges added
# n_edges_added=384 edges added
# n_edges_added=385 edges added
# n_edges_added=386 edges added
# n_edges_added=387 edges added
# n_edges_added=387 edges added
# n_edges_added=387 edges added
# n_edges_added=387 edges added
# n_edges_added=387 edges added
# n_edges_added=388 edges added
# n_edges_added=389 edges added
# n_edges_added=390 edges added
# n_edges_added=391 edges added
# n_edges_added=392 edges added
# n_edges_added=393 edges added
# n_edges_added=394 edges added
# n_edges_added=395 edges added
# n_edges_added=396 edges added
# n_edges_added=396 edges added
# n_edges_added=396 edges added
# n_edges_added=396 edges added
# n_edges_added=396 edges added
# n_edges_added=396 edges added
# n_edges_added=396 edges added
# n_edges_added=397 edges added
# n_edges_added=398 edges added
# n_edges_added=399 edges added
# n_edges_added=399 edges added
# n_edges_added=400 edges added
# n_edges_added=401 edges added
# n_edges_added=402 edges added
# n_edges_added=403 edges added
# n_edges_added=404 edges added
# n_edges_added=405 edges added
# n_edges_added=406 edges added
# n_edges_added=406 edges added
# n_edges_added=406 edges added
# n_edges_added=407 edges added
# n_edges_added=408 edges added
# n_edges_added=408 edges added
# n_edges_added=408 edges added
# n_edges_added=408 edges added
# n_edges_added=409 edges added
# n_edges_added=410 edges added
# n_edges_added=411 edges added
# n_edges_added=412 edges added
# n_edges_added=413 edges added
# n_edges_added=414 edges added
# n_edges_added=415 edges added
# n_edges_added=416 edges added
# n_edges_added=417 edges added
# n_edges_added=418 edges added
# n_edges_added=419 edges added
# n_edges_added=420 edges added
# n_edges_added=421 edges added
# n_edges_added=422 edges added
# n_edges_added=422 edges added
# n_edges_added=422 edges added
# n_edges_added=423 edges added
# n_edges_added=424 edges added
# n_edges_added=425 edges added
# n_edges_added=426 edges added
# n_edges_added=427 edges added
# n_edges_added=428 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=429 edges added
# n_edges_added=430 edges added
# n_edges_added=431 edges added
# n_edges_added=432 edges added
# n_edges_added=433 edges added
# n_edges_added=434 edges added
# n_edges_added=435 edges added
# n_edges_added=436 edges added
# n_edges_added=437 edges added
# n_edges_added=437 edges added
# n_edges_added=437 edges added
# n_edges_added=437 edges added
# n_edges_added=437 edges added
# n_edges_added=437 edges added
# n_edges_added=437 edges added
# n_edges_added=438 edges added
# n_edges_added=439 edges added
# n_edges_added=440 edges added
# n_edges_added=441 edges added
# n_edges_added=442 edges added
# n_edges_added=442 edges added
# n_edges_added=442 edges added
# n_edges_added=442 edges added
# n_edges_added=443 edges added
# n_edges_added=444 edges added
# n_edges_added=445 edges added
# n_edges_added=446 edges added
# n_edges_added=447 edges added
# n_edges_added=448 edges added
# n_edges_added=449 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=450 edges added
# n_edges_added=451 edges added
# n_edges_added=451 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=452 edges added
# n_edges_added=453 edges added
# n_edges_added=454 edges added
# n_edges_added=455 edges added
# n_edges_added=456 edges added
# n_edges_added=456 edges added
# n_edges_added=456 edges added
# n_edges_added=457 edges added
# n_edges_added=457 edges added
# n_edges_added=458 edges added
# n_edges_added=458 edges added
# n_edges_added=458 edges added
# n_edges_added=458 edges added
# n_edges_added=459 edges added
# n_edges_added=460 edges added
# n_edges_added=460 edges added
# n_edges_added=460 edges added
# n_edges_added=460 edges added
# n_edges_added=461 edges added
# n_edges_added=462 edges added
# n_edges_added=463 edges added
# n_edges_added=464 edges added
# n_edges_added=465 edges added
# n_edges_added=466 edges added
# n_edges_added=467 edges added
# n_edges_added=468 edges added
# n_edges_added=469 edges added
# n_edges_added=470 edges added
# n_edges_added=471 edges added
# n_edges_added=472 edges added
# n_edges_added=473 edges added
# n_edges_added=474 edges added
# n_edges_added=475 edges added
# n_edges_added=476 edges added
# n_edges_added=476 edges added
# n_edges_added=477 edges added
# n_edges_added=478 edges added
# n_edges_added=479 edges added
# n_edges_added=480 edges added
# n_edges_added=481 edges added
# n_edges_added=482 edges added
# n_edges_added=483 edges added
# n_edges_added=484 edges added
# n_edges_added=485 edges added
# n_edges_added=486 edges added
# n_edges_added=486 edges added
# n_edges_added=486 edges added
# n_edges_added=486 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=487 edges added
# n_edges_added=488 edges added
# n_edges_added=488 edges added
# n_edges_added=488 edges added
# n_edges_added=489 edges added
# n_edges_added=490 edges added
# n_edges_added=491 edges added
# n_edges_added=491 edges added
# n_edges_added=491 edges added
# n_edges_added=492 edges added
# n_edges_added=493 edges added
# n_edges_added=493 edges added
# n_edges_added=493 edges added
# n_edges_added=493 edges added
# n_edges_added=493 edges added
# n_edges_added=493 edges added
# n_edges_added=493 edges added
# n_edges_added=493 edges added
# n_edges_added=494 edges added
# n_edges_added=495 edges added
# n_edges_added=496 edges added
# n_edges_added=497 edges added
# n_edges_added=498 edges added
# n_edges_added=499 edges added
# n_edges_added=500 edges added
# n_edges_added=501 edges added
# n_edges_added=502 edges added
# n_edges_added=503 edges added
# n_edges_added=504 edges added
# n_edges_added=505 edges added
# n_edges_added=506 edges added
# n_edges_added=507 edges added
# n_edges_added=508 edges added
# n_edges_added=509 edges added
# n_edges_added=510 edges added
# n_edges_added=510 edges added
# n_edges_added=510 edges added
# n_edges_added=510 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=511 edges added
# n_edges_added=512 edges added
# n_edges_added=513 edges added
# n_edges_added=513 edges added
# n_edges_added=513 edges added
# n_edges_added=513 edges added
# n_edges_added=514 edges added
# n_edges_added=514 edges added
# n_edges_added=514 edges added
# n_edges_added=514 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=515 edges added
# n_edges_added=516 edges added
# n_edges_added=516 edges added
# n_edges_added=516 edges added
# n_edges_added=516 edges added
# n_edges_added=516 edges added
# n_edges_added=516 edges added
# n_edges_added=517 edges added
# n_edges_added=518 edges added
# n_edges_added=519 edges added
# n_edges_added=519 edges added
# n_edges_added=519 edges added
# n_edges_added=520 edges added
# n_edges_added=521 edges added
# n_edges_added=521 edges added
# n_edges_added=522 edges added
# n_edges_added=522 edges added
# n_edges_added=522 edges added
# n_edges_added=523 edges added
# n_edges_added=524 edges added
# n_edges_added=525 edges added
# n_edges_added=526 edges added
# n_edges_added=527 edges added
# n_edges_added=528 edges added
# n_edges_added=529 edges added
# n_edges_added=530 edges added
# n_edges_added=531 edges added
# n_edges_added=532 edges added
# n_edges_added=533 edges added
# n_edges_added=534 edges added
# n_edges_added=534 edges added
# n_edges_added=535 edges added
# n_edges_added=536 edges added
# n_edges_added=537 edges added
# n_edges_added=538 edges added
# n_edges_added=539 edges added
# n_edges_added=540 edges added
# n_edges_added=541 edges added
# n_edges_added=542 edges added
# n_edges_added=543 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=544 edges added
# n_edges_added=545 edges added
# n_edges_added=545 edges added
# n_edges_added=546 edges added
# n_edges_added=547 edges added
# n_edges_added=548 edges added
# n_edges_added=549 edges added
# n_edges_added=550 edges added
# n_edges_added=551 edges added
# n_edges_added=552 edges added
# n_edges_added=553 edges added
# n_edges_added=553 edges added
# n_edges_added=553 edges added
# n_edges_added=554 edges added
# n_edges_added=555 edges added
# n_edges_added=555 edges added
# n_edges_added=555 edges added
# n_edges_added=555 edges added
# n_edges_added=556 edges added
# n_edges_added=557 edges added
# n_edges_added=557 edges added
# n_edges_added=557 edges added
# n_edges_added=557 edges added
# n_edges_added=558 edges added
# n_edges_added=559 edges added
# n_edges_added=560 edges added
# n_edges_added=560 edges added
# n_edges_added=561 edges added
# n_edges_added=561 edges added
# n_edges_added=562 edges added
# n_edges_added=563 edges added
# n_edges_added=564 edges added
# n_edges_added=565 edges added
# n_edges_added=566 edges added
# n_edges_added=567 edges added
# n_edges_added=568 edges added
# n_edges_added=569 edges added
# n_edges_added=570 edges added
# n_edges_added=571 edges added
# n_edges_added=572 edges added
# n_edges_added=573 edges added
# n_edges_added=574 edges added
# n_edges_added=575 edges added
# n_edges_added=576 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=577 edges added
# n_edges_added=578 edges added
# n_edges_added=578 edges added
# n_edges_added=578 edges added
# n_edges_added=579 edges added
# n_edges_added=579 edges added
# n_edges_added=579 edges added
# n_edges_added=580 edges added
# n_edges_added=581 edges added
# n_edges_added=582 edges added
# n_edges_added=583 edges added
# n_edges_added=584 edges added
# n_edges_added=585 edges added
# n_edges_added=586 edges added
# n_edges_added=586 edges added
# n_edges_added=586 edges added
# n_edges_added=586 edges added
# n_edges_added=586 edges added
# n_edges_added=586 edges added
# n_edges_added=587 edges added
# n_edges_added=587 edges added
# n_edges_added=588 edges added
# n_edges_added=589 edges added
# n_edges_added=589 edges added
# n_edges_added=590 edges added
# n_edges_added=591 edges added
# n_edges_added=592 edges added
# n_edges_added=593 edges added
# n_edges_added=594 edges added
# n_edges_added=595 edges added
# n_edges_added=596 edges added
# n_edges_added=597 edges added
# n_edges_added=598 edges added
# n_edges_added=598 edges added
# n_edges_added=599 edges added
# n_edges_added=600 edges added
# n_edges_added=601 edges added
# n_edges_added=602 edges added
# n_edges_added=603 edges added
# n_edges_added=604 edges added
# n_edges_added=604 edges added
# n_edges_added=604 edges added
# n_edges_added=604 edges added
# n_edges_added=604 edges added
# n_edges_added=604 edges added
# n_edges_added=604 edges added
# n_edges_added=604 edges added
# n_edges_added=605 edges added
# n_edges_added=606 edges added
# n_edges_added=606 edges added
# n_edges_added=607 edges added
# n_edges_added=608 edges added
# n_edges_added=609 edges added
# n_edges_added=610 edges added
# n_edges_added=611 edges added
# n_edges_added=612 edges added
# n_edges_added=613 edges added
# n_edges_added=614 edges added
# n_edges_added=615 edges added
# n_edges_added=616 edges added
# n_edges_added=617 edges added
# n_edges_added=618 edges added
# n_edges_added=619 edges added
# n_edges_added=620 edges added
# n_edges_added=621 edges added
# n_edges_added=622 edges added
# n_edges_added=623 edges added
# n_edges_added=623 edges added
# n_edges_added=623 edges added
# n_edges_added=623 edges added
# n_edges_added=623 edges added
# n_edges_added=623 edges added
# n_edges_added=623 edges added
# n_edges_added=624 edges added
# n_edges_added=625 edges added
# n_edges_added=626 edges added
# n_edges_added=626 edges added
# n_edges_added=626 edges added
# n_edges_added=626 edges added
# n_edges_added=626 edges added
# n_edges_added=626 edges added
# n_edges_added=627 edges added
# n_edges_added=628 edges added
# n_edges_added=629 edges added
# n_edges_added=630 edges added
# n_edges_added=631 edges added
# n_edges_added=631 edges added
# n_edges_added=631 edges added
# n_edges_added=631 edges added
# n_edges_added=631 edges added
# n_edges_added=632 edges added
# n_edges_added=633 edges added
# n_edges_added=633 edges added
# n_edges_added=633 edges added
# n_edges_added=634 edges added
# n_edges_added=635 edges added
# n_edges_added=636 edges added
# n_edges_added=637 edges added
# n_edges_added=638 edges added
# n_edges_added=639 edges added
# n_edges_added=640 edges added
# n_edges_added=641 edges added
# n_edges_added=642 edges added
# n_edges_added=643 edges added
# n_edges_added=644 edges added
# n_edges_added=645 edges added
# n_edges_added=646 edges added
# n_edges_added=647 edges added
# n_edges_added=648 edges added
# n_edges_added=648 edges added
# n_edges_added=648 edges added
# n_edges_added=648 edges added
# n_edges_added=648 edges added
# n_edges_added=648 edges added
# n_edges_added=649 edges added
# n_edges_added=650 edges added
# n_edges_added=651 edges added
# n_edges_added=652 edges added
# n_edges_added=653 edges added
# n_edges_added=654 edges added
# n_edges_added=655 edges added
# n_edges_added=656 edges added
# n_edges_added=657 edges added
# n_edges_added=658 edges added
# n_edges_added=659 edges added
# n_edges_added=660 edges added
# n_edges_added=661 edges added
# n_edges_added=662 edges added
# n_edges_added=663 edges added
# n_edges_added=664 edges added
# n_edges_added=665 edges added
# n_edges_added=666 edges added
# n_edges_added=667 edges added
# n_edges_added=668 edges added
# n_edges_added=669 edges added
# n_edges_added=670 edges added
# n_edges_added=671 edges added
# n_edges_added=672 edges added
# n_edges_added=673 edges added
# n_edges_added=673 edges added
# n_edges_added=674 edges added
# n_edges_added=674 edges added
# n_edges_added=674 edges added
# n_edges_added=674 edges added
# n_edges_added=675 edges added
# n_edges_added=676 edges added
# n_edges_added=677 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=678 edges added
# n_edges_added=679 edges added
# n_edges_added=679 edges added
# n_edges_added=680 edges added
# n_edges_added=681 edges added
# n_edges_added=681 edges added
# n_edges_added=681 edges added
# n_edges_added=681 edges added
# n_edges_added=681 edges added
# n_edges_added=682 edges added
# n_edges_added=682 edges added
# n_edges_added=682 edges added
# n_edges_added=682 edges added
# n_edges_added=682 edges added
# n_edges_added=682 edges added
# n_edges_added=682 edges added
# n_edges_added=682 edges added
# n_edges_added=683 edges added
# n_edges_added=683 edges added
# n_edges_added=684 edges added
# n_edges_added=684 edges added
# n_edges_added=684 edges added
# n_edges_added=684 edges added
# n_edges_added=685 edges added
# n_edges_added=685 edges added
# n_edges_added=685 edges added
# n_edges_added=685 edges added
# n_edges_added=686 edges added
# n_edges_added=687 edges added
# n_edges_added=687 edges added
# n_edges_added=688 edges added
# n_edges_added=689 edges added
# n_edges_added=689 edges added
# n_edges_added=689 edges added
# n_edges_added=689 edges added
# n_edges_added=689 edges added
# n_edges_added=689 edges added
# n_edges_added=689 edges added
# n_edges_added=689 edges added
# n_edges_added=690 edges added
# n_edges_added=691 edges added
# n_edges_added=692 edges added
# n_edges_added=693 edges added
# n_edges_added=694 edges added
# n_edges_added=695 edges added
# n_edges_added=696 edges added
# n_edges_added=697 edges added
# n_edges_added=698 edges added
# n_edges_added=699 edges added
# n_edges_added=700 edges added
# n_edges_added=701 edges added
# n_edges_added=701 edges added
# n_edges_added=701 edges added
# n_edges_added=701 edges added
# n_edges_added=701 edges added
# n_edges_added=702 edges added
# n_edges_added=702 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=703 edges added
# n_edges_added=704 edges added
# n_edges_added=705 edges added
# n_edges_added=706 edges added
# n_edges_added=707 edges added
# n_edges_added=708 edges added
# n_edges_added=709 edges added
# n_edges_added=710 edges added
# n_edges_added=711 edges added
# n_edges_added=712 edges added
# n_edges_added=713 edges added
# n_edges_added=714 edges added
# n_edges_added=715 edges added
# n_edges_added=716 edges added
# n_edges_added=717 edges added
# n_edges_added=718 edges added
# n_edges_added=719 edges added
# n_edges_added=720 edges added
# n_edges_added=721 edges added
# n_edges_added=722 edges added
# n_edges_added=723 edges added
# n_edges_added=724 edges added
# n_edges_added=725 edges added
# n_edges_added=726 edges added
# n_edges_added=727 edges added
# n_edges_added=728 edges added
# n_edges_added=729 edges added
# n_edges_added=729 edges added
# n_edges_added=729 edges added
# n_edges_added=729 edges added
# n_edges_added=729 edges added
# n_edges_added=730 edges added
# n_edges_added=730 edges added
# n_edges_added=731 edges added
# n_edges_added=732 edges added
# n_edges_added=732 edges added
# n_edges_added=732 edges added
# n_edges_added=732 edges added
# n_edges_added=733 edges added
# n_edges_added=734 edges added
# n_edges_added=734 edges added
# n_edges_added=734 edges added
# n_edges_added=734 edges added
# n_edges_added=734 edges added
# n_edges_added=735 edges added
# n_edges_added=736 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=737 edges added
# n_edges_added=738 edges added
# n_edges_added=738 edges added
# n_edges_added=739 edges added
# n_edges_added=740 edges added
# n_edges_added=740 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=741 edges added
# n_edges_added=742 edges added
# n_edges_added=743 edges added
# n_edges_added=743 edges added
# n_edges_added=744 edges added
# n_edges_added=744 edges added
# n_edges_added=744 edges added
# n_edges_added=744 edges added
# n_edges_added=745 edges added
# n_edges_added=745 edges added
# n_edges_added=746 edges added
# n_edges_added=747 edges added
# n_edges_added=748 edges added
# n_edges_added=748 edges added
# n_edges_added=749 edges added
# n_edges_added=749 edges added
# n_edges_added=749 edges added
# n_edges_added=749 edges added
# n_edges_added=749 edges added
# n_edges_added=749 edges added
# n_edges_added=749 edges added
# n_edges_added=750 edges added
# n_edges_added=751 edges added
# n_edges_added=752 edges added
# n_edges_added=753 edges added
# n_edges_added=754 edges added
# n_edges_added=755 edges added
# n_edges_added=756 edges added
# n_edges_added=757 edges added
# n_edges_added=758 edges added
# n_edges_added=758 edges added
# n_edges_added=759 edges added
# n_edges_added=760 edges added
# n_edges_added=760 edges added
# n_edges_added=761 edges added
# n_edges_added=761 edges added
# n_edges_added=761 edges added
# n_edges_added=761 edges added
# n_edges_added=762 edges added
# n_edges_added=763 edges added
# n_edges_added=764 edges added
# n_edges_added=765 edges added
# n_edges_added=766 edges added
# n_edges_added=767 edges added
# n_edges_added=768 edges added
# n_edges_added=769 edges added
# n_edges_added=770 edges added
# n_edges_added=771 edges added
# n_edges_added=772 edges added
# n_edges_added=773 edges added
# n_edges_added=774 edges added
# n_edges_added=775 edges added
# n_edges_added=776 edges added
# n_edges_added=777 edges added
# n_edges_added=778 edges added
# n_edges_added=779 edges added
# n_edges_added=779 edges added
# n_edges_added=780 edges added
# n_edges_added=781 edges added
# n_edges_added=782 edges added
# n_edges_added=783 edges added
# n_edges_added=784 edges added
# n_edges_added=784 edges added
# n_edges_added=785 edges added
# n_edges_added=786 edges added
# n_edges_added=786 edges added
# n_edges_added=786 edges added
# n_edges_added=786 edges added
# n_edges_added=787 edges added
# n_edges_added=787 edges added
# n_edges_added=787 edges added
# n_edges_added=788 edges added
# n_edges_added=789 edges added
# n_edges_added=790 edges added
# n_edges_added=791 edges added
# n_edges_added=792 edges added
# n_edges_added=793 edges added
# n_edges_added=794 edges added
# n_edges_added=795 edges added
# n_edges_added=796 edges added
# n_edges_added=797 edges added
# n_edges_added=798 edges added
# n_edges_added=799 edges added
# n_edges_added=800 edges added
# n_edges_added=801 edges added
# n_edges_added=802 edges added
# n_edges_added=803 edges added
# n_edges_added=804 edges added
# n_edges_added=804 edges added
# n_edges_added=804 edges added
# n_edges_added=805 edges added
# n_edges_added=805 edges added
# n_edges_added=806 edges added
# n_edges_added=807 edges added
# n_edges_added=808 edges added
# n_edges_added=808 edges added
# n_edges_added=808 edges added
# n_edges_added=809 edges added
# n_edges_added=810 edges added
# n_edges_added=811 edges added
# n_edges_added=812 edges added
# n_edges_added=813 edges added
# n_edges_added=814 edges added
# n_edges_added=815 edges added
# n_edges_added=816 edges added
# n_edges_added=817 edges added
# n_edges_added=818 edges added
# n_edges_added=819 edges added
# n_edges_added=820 edges added
# n_edges_added=821 edges added
# n_edges_added=822 edges added
# n_edges_added=823 edges added
# n_edges_added=824 edges added
# n_edges_added=825 edges added
# n_edges_added=826 edges added
# n_edges_added=827 edges added
# n_edges_added=828 edges added
# n_edges_added=829 edges added
# n_edges_added=829 edges added
# n_edges_added=830 edges added
# n_edges_added=830 edges added
# n_edges_added=831 edges added
# n_edges_added=832 edges added
# n_edges_added=833 edges added
# n_edges_added=834 edges added
# n_edges_added=835 edges added
# n_edges_added=836 edges added
# n_edges_added=837 edges added
# n_edges_added=838 edges added
# n_edges_added=839 edges added
# n_edges_added=840 edges added
# n_edges_added=841 edges added
# n_edges_added=842 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=843 edges added
# n_edges_added=844 edges added
# n_edges_added=845 edges added
# n_edges_added=846 edges added
# n_edges_added=847 edges added
# n_edges_added=848 edges added
# n_edges_added=849 edges added
# n_edges_added=850 edges added
# n_edges_added=851 edges added
# n_edges_added=852 edges added
# n_edges_added=853 edges added
# n_edges_added=854 edges added
# n_edges_added=855 edges added
# n_edges_added=856 edges added
# n_edges_added=857 edges added
# n_edges_added=858 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=859 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=860 edges added
# n_edges_added=861 edges added
# n_edges_added=862 edges added
# n_edges_added=863 edges added
# n_edges_added=864 edges added
# n_edges_added=865 edges added
# n_edges_added=866 edges added
# n_edges_added=867 edges added
# n_edges_added=868 edges added
# n_edges_added=869 edges added
# n_edges_added=870 edges added
# n_edges_added=871 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=872 edges added
# n_edges_added=873 edges added
# n_edges_added=873 edges added
# n_edges_added=873 edges added
# n_edges_added=873 edges added
# n_edges_added=873 edges added
# n_edges_added=874 edges added
# n_edges_added=875 edges added
# n_edges_added=876 edges added
# n_edges_added=877 edges added
# n_edges_added=878 edges added
# n_edges_added=879 edges added
# n_edges_added=880 edges added
# n_edges_added=881 edges added
# n_edges_added=882 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=883 edges added
# n_edges_added=884 edges added
# n_edges_added=885 edges added
# n_edges_added=886 edges added
# n_edges_added=886 edges added
# n_edges_added=886 edges added
# n_edges_added=886 edges added
# n_edges_added=886 edges added
# n_edges_added=887 edges added
# n_edges_added=888 edges added
# n_edges_added=888 edges added
# n_edges_added=889 edges added
# n_edges_added=889 edges added
# n_edges_added=889 edges added
# n_edges_added=889 edges added
# n_edges_added=890 edges added
# n_edges_added=891 edges added
# n_edges_added=892 edges added
# n_edges_added=893 edges added
# n_edges_added=894 edges added
# n_edges_added=895 edges added
# n_edges_added=896 edges added
# n_edges_added=897 edges added
# n_edges_added=898 edges added
# n_edges_added=899 edges added
# n_edges_added=900 edges added
# n_edges_added=901 edges added
# n_edges_added=901 edges added
# n_edges_added=901 edges added
# n_edges_added=901 edges added
# n_edges_added=901 edges added
# n_edges_added=901 edges added
# n_edges_added=902 edges added
# n_edges_added=903 edges added
# n_edges_added=904 edges added
# n_edges_added=905 edges added
# n_edges_added=905 edges added
# n_edges_added=905 edges added
# n_edges_added=905 edges added
# n_edges_added=905 edges added
# n_edges_added=905 edges added
# n_edges_added=905 edges added
# n_edges_added=905 edges added
# n_edges_added=906 edges added
# n_edges_added=907 edges added
# n_edges_added=907 edges added
# n_edges_added=907 edges added
# n_edges_added=907 edges added
# n_edges_added=907 edges added
# n_edges_added=907 edges added
# n_edges_added=907 edges added
# n_edges_added=908 edges added
# n_edges_added=908 edges added
# n_edges_added=909 edges added
# n_edges_added=909 edges added
# n_edges_added=909 edges added
# n_edges_added=909 edges added
# n_edges_added=909 edges added
# n_edges_added=909 edges added
# n_edges_added=910 edges added
# n_edges_added=911 edges added
# n_edges_added=912 edges added
# n_edges_added=913 edges added
# n_edges_added=914 edges added
# n_edges_added=915 edges added
# n_edges_added=916 edges added
# n_edges_added=917 edges added
# n_edges_added=918 edges added
# n_edges_added=919 edges added
# n_edges_added=919 edges added
# n_edges_added=919 edges added
# n_edges_added=919 edges added
# n_edges_added=919 edges added
# n_edges_added=919 edges added
# n_edges_added=919 edges added
# n_edges_added=920 edges added
# n_edges_added=921 edges added
# n_edges_added=922 edges added
# n_edges_added=922 edges added
# n_edges_added=922 edges added
# n_edges_added=922 edges added
# n_edges_added=922 edges added
# n_edges_added=922 edges added
# n_edges_added=922 edges added
# n_edges_added=923 edges added
# n_edges_added=923 edges added
# n_edges_added=923 edges added
# n_edges_added=924 edges added
# n_edges_added=924 edges added
# n_edges_added=924 edges added
# n_edges_added=924 edges added
# n_edges_added=925 edges added
# n_edges_added=926 edges added
# n_edges_added=927 edges added
# n_edges_added=928 edges added
# n_edges_added=929 edges added
# n_edges_added=930 edges added
# n_edges_added=931 edges added
# n_edges_added=932 edges added
# n_edges_added=933 edges added
# n_edges_added=934 edges added
# n_edges_added=934 edges added
# n_edges_added=934 edges added
# n_edges_added=935 edges added
# n_edges_added=936 edges added
# n_edges_added=937 edges added
# n_edges_added=938 edges added
# n_edges_added=939 edges added
# n_edges_added=940 edges added
# n_edges_added=941 edges added
# n_edges_added=942 edges added
# n_edges_added=942 edges added
# n_edges_added=942 edges added
# n_edges_added=943 edges added
# n_edges_added=943 edges added
# n_edges_added=943 edges added
# n_edges_added=943 edges added
# n_edges_added=943 edges added
# n_edges_added=943 edges added
# n_edges_added=943 edges added
# n_edges_added=944 edges added
# n_edges_added=944 edges added
# n_edges_added=944 edges added
# n_edges_added=944 edges added
# n_edges_added=944 edges added
# n_edges_added=944 edges added
# n_edges_added=944 edges added
# n_edges_added=945 edges added
# n_edges_added=945 edges added
# n_edges_added=945 edges added
# n_edges_added=945 edges added
# n_edges_added=946 edges added
# n_edges_added=946 edges added
# n_edges_added=946 edges added
# n_edges_added=947 edges added
# n_edges_added=947 edges added
# n_edges_added=947 edges added
# n_edges_added=947 edges added
# n_edges_added=947 edges added
# n_edges_added=948 edges added
# n_edges_added=948 edges added
# n_edges_added=948 edges added
# n_edges_added=948 edges added
# n_edges_added=948 edges added
# n_edges_added=948 edges added
# n_edges_added=948 edges added
# n_edges_added=949 edges added
# n_edges_added=950 edges added
# n_edges_added=951 edges added
# n_edges_added=951 edges added
# n_edges_added=951 edges added
# n_edges_added=951 edges added
# n_edges_added=951 edges added
# n_edges_added=951 edges added
# n_edges_added=951 edges added
# n_edges_added=952 edges added
# n_edges_added=953 edges added
# n_edges_added=954 edges added
# n_edges_added=955 edges added
# n_edges_added=955 edges added
# n_edges_added=955 edges added
# n_edges_added=955 edges added
# n_edges_added=956 edges added
# n_edges_added=957 edges added
# n_edges_added=958 edges added
# n_edges_added=959 edges added
# n_edges_added=959 edges added
# n_edges_added=959 edges added
# n_edges_added=959 edges added
# n_edges_added=959 edges added
# n_edges_added=959 edges added
# n_edges_added=959 edges added
# n_edges_added=959 edges added
# n_edges_added=960 edges added
# n_edges_added=960 edges added
# n_edges_added=960 edges added
# n_edges_added=960 edges added
# n_edges_added=960 edges added
# n_edges_added=960 edges added
# n_edges_added=961 edges added
# n_edges_added=962 edges added
# n_edges_added=963 edges added
# n_edges_added=964 edges added
# n_edges_added=965 edges added
# n_edges_added=965 edges added
# n_edges_added=965 edges added
# n_edges_added=965 edges added
# n_edges_added=965 edges added
# n_edges_added=965 edges added
# n_edges_added=965 edges added
# n_edges_added=965 edges added
# n_edges_added=966 edges added
# n_edges_added=966 edges added
# n_edges_added=966 edges added
# n_edges_added=967 edges added
# n_edges_added=968 edges added
# n_edges_added=969 edges added
# n_edges_added=969 edges added
# n_edges_added=969 edges added
# n_edges_added=970 edges added
# n_edges_added=971 edges added
# n_edges_added=972 edges added
# n_edges_added=973 edges added
# n_edges_added=974 edges added
# n_edges_added=975 edges added
# n_edges_added=976 edges added
# n_edges_added=977 edges added
# n_edges_added=978 edges added
# n_edges_added=979 edges added
# n_edges_added=980 edges added
# n_edges_added=981 edges added
# n_edges_added=982 edges added
# n_edges_added=983 edges added
# n_edges_added=984 edges added
# n_edges_added=985 edges added
# n_edges_added=986 edges added
# n_edges_added=987 edges added
# n_edges_added=988 edges added
# n_edges_added=989 edges added
# n_edges_added=990 edges added
# n_edges_added=991 edges added
# n_edges_added=992 edges added
# n_edges_added=993 edges added
# n_edges_added=994 edges added
# n_edges_added=995 edges added
# n_edges_added=996 edges added
# n_edges_added=996 edges added
# n_edges_added=996 edges added
# n_edges_added=996 edges added
# n_edges_added=996 edges added
# n_edges_added=996 edges added
# n_edges_added=997 edges added
# n_edges_added=998 edges added
# n_edges_added=998 edges added
# n_edges_added=998 edges added
# n_edges_added=998 edges added
# n_edges_added=998 edges added
# n_edges_added=998 edges added
# n_edges_added=998 edges added
# n_edges_added=999 edges added
# n_edges_added=1,000 edges added
# 240 edges added to increase clustering
# 760 edges added based on uniform degree distribution

# %%
data_densify_fancy = {
    "network": ["original", "densify_fancy_0100", "densify_fancy_0500", "densify_fancy_1000"], #, "cluster_constant_2", "cluster_constant_3", "cluster_constant_4", "cluster_constant_5"],
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(densify_fancy_01, directed=True),
        calculate_degree_gini(densify_fancy_05, directed=True),
        calculate_degree_gini(densify_fancy_1, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(densify_fancy_01),
        nx.average_clustering(densify_fancy_05),
        nx.average_clustering(densify_fancy_1)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(densify_fancy_01),
        nx.density(densify_fancy_05),
        nx.density(densify_fancy_1)
    ]
}

df_densify_fancy = pd.DataFrame(data_densify_fancy)
df_densify_fancy
# Out:
#               network  degree_gini  clustering_coefficient   density
# 0            original     0.722814                0.117170  0.000735
# 1  densify_fancy_0100     0.720763                0.117169  0.000738
# 2  densify_fancy_0500     0.713101                0.117234  0.000750
# 3  densify_fancy_1000     0.702322                0.117177  0.000766

# %%
densify_fancy_speedy_1000 = densify_fancy_speed_up(network_pud, n_edges=1000, target_degree_dist="uniform")
densify_fancy_speedy_2000 = densify_fancy_speed_up(network_pud, n_edges=2000, target_degree_dist="uniform")
densify_fancy_speedy_3000 = densify_fancy_speed_up(network_pud, n_edges=3000, target_degree_dist="uniform")
densify_fancy_speedy_4000 = densify_fancy_speed_up(network_pud, n_edges=4000, target_degree_dist="uniform")
densify_fancy_speedy_5000 = densify_fancy_speed_up(network_pud, n_edges=5000, target_degree_dist="uniform")
# Out:
# 289 edges added to increase clustering
# 711 edges added based on uniform degree distribution
# 637 edges added to increase clustering
# 1,363 edges added based on uniform degree distribution
# 1,053 edges added to increase clustering
# 1,947 edges added based on uniform degree distribution
# 1,576 edges added to increase clustering
# 2,424 edges added based on uniform degree distribution
# 2,270 edges added to increase clustering
# 2,730 edges added based on uniform degree distribution

# %%
data_densify_fancy = {
    "network": ["original", "densify_fancy_speedy_1000", "densify_fancy_speedy_2000", "densify_fancy_speedy_3000", "densify_fancy_speedy_4000", "densify_fancy_speedy_5000"], 
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(densify_fancy_speedy_1000, directed=True),
        calculate_degree_gini(densify_fancy_speedy_2000, directed=True),
        calculate_degree_gini(densify_fancy_speedy_3000, directed=True),
        calculate_degree_gini(densify_fancy_speedy_4000, directed=True),
        calculate_degree_gini(densify_fancy_speedy_5000, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(densify_fancy_speedy_1000),
        nx.average_clustering(densify_fancy_speedy_2000),
        nx.average_clustering(densify_fancy_speedy_3000),
        nx.average_clustering(densify_fancy_speedy_4000),
        nx.average_clustering(densify_fancy_speedy_5000)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(densify_fancy_speedy_1000),
        nx.density(densify_fancy_speedy_2000),
        nx.density(densify_fancy_speedy_3000),
        nx.density(densify_fancy_speedy_4000),
        nx.density(densify_fancy_speedy_5000)
    ]
}

df_densify_fancy_speedy = pd.DataFrame(data_densify_fancy)
df_densify_fancy_speedy
# Out:
#                      network  degree_gini  clustering_coefficient   density
# 0                   original     0.722814                0.117170  0.000735
# 1  densify_fancy_speedy_1000     0.703094                0.117106  0.000766
# 2  densify_fancy_speedy_2000     0.685722                0.117190  0.000796
# 3  densify_fancy_speedy_3000     0.670560                0.117202  0.000826
# 4  densify_fancy_speedy_4000     0.659583                0.117167  0.000852
# 5  densify_fancy_speedy_5000     0.651527                0.117351  0.000874

# %% [markdown]
# ## Cluster

# %%
decluster_net_1 = decluster(network_pud, n_triangles=1000)
print("Done")
decluster_net_2 = decluster(network_pud, n_triangles=2000)
print("Done")
decluster_net_3 = decluster(network_pud, n_triangles=3000)    
print("Done")
decluster_net_4 = decluster(network_pud, n_triangles=4000)
print("Done")
decluster_net_5 = decluster(network_pud, n_triangles=5000)
# Out:
# Done
# Done
# Done
# Done

# %%
data_decluster = {
    "network": ["original", "declustered_1000", "declustered_2000", "declustered_3000", "declustered_4000", "declustered_5000"],
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(decluster_net_1, directed=True),
        calculate_degree_gini(decluster_net_2, directed=True),
        calculate_degree_gini(decluster_net_3, directed=True),
        calculate_degree_gini(decluster_net_4, directed=True),
        calculate_degree_gini(decluster_net_5, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(decluster_net_1),
        nx.average_clustering(decluster_net_2),
        nx.average_clustering(decluster_net_3),
        nx.average_clustering(decluster_net_4),
        nx.average_clustering(decluster_net_5)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(decluster_net_1),
        nx.density(decluster_net_2),
        nx.density(decluster_net_3),
        nx.density(decluster_net_4),
        nx.density(decluster_net_5)
    ]
}

df_decluster = pd.DataFrame(data_decluster)
df_decluster
# Out:
#             network  degree_gini  clustering_coefficient   density
# 0          original     0.722814                0.117170  0.000735
# 1  declustered_1000     0.716609                0.089386  0.000735
# 2  declustered_2000     0.711989                0.073236  0.000735
# 3  declustered_3000     0.709279                0.058899  0.000735
# 4  declustered_4000     0.706405                0.050909  0.000735
# 5  declustered_5000     0.704724                0.044131  0.000735

# %%
cluster_network_1 = cluster_network(network_pud, n=1000)
print("Done")
cluster_network_2 = cluster_network(network_pud, n=2000)
print("Done")
cluster_network_3 = cluster_network(network_pud, n=3000)
print("Done")
cluster_network_4 = cluster_network(network_pud, n=4000)
print("Done")
# Out:
# n_edges_to_add=1,000
# Done
# n_edges_to_add=2,000
# Done
# n_edges_to_add=3,000
# Done
# n_edges_to_add=4,000
# Done

# %%
data_cluster = {
    "network": ["original", "clustered_1000", "clustered_2000", "clustered_3000", "clustered_4000"],
    "degree_gini": [
        calculate_degree_gini(network_pud, directed=True),
        calculate_degree_gini(cluster_network_1, directed=True),
        calculate_degree_gini(cluster_network_2, directed=True),
        calculate_degree_gini(cluster_network_3, directed=True),
        calculate_degree_gini(cluster_network_4, directed=True)
    ],
    "clustering_coefficient": [
        nx.average_clustering(network_pud),
        nx.average_clustering(cluster_network_1),
        nx.average_clustering(cluster_network_2),
        nx.average_clustering(cluster_network_3),
        nx.average_clustering(cluster_network_4)
    ],
    "density": [
        nx.density(network_pud),
        nx.density(cluster_network_1),
        nx.density(cluster_network_2),
        nx.density(cluster_network_3),
        nx.density(cluster_network_4)
    ]
}

df_cluster = pd.DataFrame(data_cluster)
df_cluster
# Out:
#           network  degree_gini  clustering_coefficient   density
# 0        original     0.722814                0.117170  0.000735
# 1  clustered_1000     0.717003                0.157702  0.000764
# 2  clustered_2000     0.713696                0.178848  0.000793
# 3  clustered_3000     0.710527                0.191312  0.000822
# 4  clustered_4000     0.711583                0.201278  0.000852

# %% [markdown]
# ## Outcomes

# %%
df_random
# Out:
#       network  degree_gini  clustering_coefficient   density
# 0    original     0.722814                0.117170  0.000735
# 1  random_10%     0.671672                0.073970  0.000735
# 2  random_20%     0.615289                0.048422  0.000735
# 3  random_30%     0.562563                0.031578  0.000735
# 4  random_40%     0.507131                0.019903  0.000735
# 5  random_50%     0.456154                0.011539  0.000735

# %%
df_equalize
# Out:
#           network  degree_gini  clustering_coefficient   density
# 0        original     0.722814                0.117170  0.000735
# 1  equalized_1000     0.712783                0.107457  0.000735
# 2  equalized_2000     0.702656                0.103614  0.000735
# 3  equalized_3000     0.695547                0.098000  0.000735
# 4  equalized_4000     0.689827                0.094092  0.000735
# 5  equalized_5000     0.684853                0.089313  0.000735

# %%
df_densify
# Out:
#           network  degree_gini  clustering_coefficient   density
# 0        original     0.722814                0.117170  0.000735
# 1  densified_1000     0.724220                0.110193  0.000768
# 2  densified_2000     0.724283                0.102803  0.000801
# 3  densified_3000     0.726149                0.097371  0.000834
# 4  densified_4000     0.726985                0.089387  0.000867
# 5  densified_5000     0.725842                0.085490  0.000900

# %%
df_densify_semi
# Out:
#                      network  degree_gini  clustering_coefficient   density
# 0                   original     0.722814                0.117170  0.000735
# 1  densified_semi_fancy_1000     0.705396                0.119901  0.000766
# 2  densified_semi_fancy_2000     0.686549                0.118471  0.000796
# 3  densified_semi_fancy_3000     0.672463                0.117202  0.000825
# 4  densified_semi_fancy_4000     0.654503                0.110578  0.000857
# 5  densified_semi_fancy_5000     0.641581                0.104283  0.000884

# %%
df_densify_fancy
# Out:
#               network  degree_gini  clustering_coefficient   density
# 0            original     0.722814                0.117170  0.000735
# 1  densify_fancy_0100     0.720763                0.117169  0.000738
# 2  densify_fancy_0500     0.713101                0.117234  0.000750
# 3  densify_fancy_1000     0.702322                0.117177  0.000766

# %%
df_densify_fancy_speedy
# Out:
#                      network  degree_gini  clustering_coefficient   density
# 0                   original     0.722814                0.117170  0.000735
# 1  densify_fancy_speedy_1000     0.703094                0.117106  0.000766
# 2  densify_fancy_speedy_2000     0.685722                0.117190  0.000796
# 3  densify_fancy_speedy_3000     0.670560                0.117202  0.000826
# 4  densify_fancy_speedy_4000     0.659583                0.117167  0.000852
# 5  densify_fancy_speedy_5000     0.651527                0.117351  0.000874

# %%
df_decluster
# Out:
#             network  degree_gini  clustering_coefficient   density
# 0          original     0.722814                0.117170  0.000735
# 1  declustered_1000     0.716609                0.089386  0.000735
# 2  declustered_2000     0.711989                0.073236  0.000735
# 3  declustered_3000     0.709279                0.058899  0.000735
# 4  declustered_4000     0.706405                0.050909  0.000735
# 5  declustered_5000     0.704724                0.044131  0.000735

# %%
df_cluster
# Out:
#           network  degree_gini  clustering_coefficient   density
# 0        original     0.722814                0.117170  0.000735
# 1  clustered_1000     0.717003                0.157702  0.000764
# 2  clustered_2000     0.713696                0.178848  0.000793
# 3  clustered_3000     0.710527                0.191312  0.000822
# 4  clustered_4000     0.711583                0.201278  0.000852
