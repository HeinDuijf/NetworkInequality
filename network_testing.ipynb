# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_randomization import *
from network_generation import *

# %% [markdown]
# # Generated Networks

# %%
for rdmize in [0,0.25,0.5,0.75,1]:
    G = barabasi_albert_directed(1000, 5)
    G = randomize_network(G, rdmize)
    plot_network_degree_distribution(G, title=f'Randomization: {rdmize}')
    plot_loglog(G,m=2)
    stats = network_statistics(G)
    for key in stats:
        print(f"{key}: {stats[key]}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 for rdmize in [0,0.25,0.5,0.75,1]:
# ----> 2     G = barabasi_albert_directed(1000, 5)
#       3     G = randomize_network(G, rdmize)
#       4     plot_network_degree_distribution(G, title=f'Randomization: {rdmize}')
#
# File ~/GitRepositories/e_network_inequality/network_generation.py:34, in barabasi_albert_directed(n, m)
#      30 G.add_node(new_node)
#      32 # Calculate the total out-degree of all existing nodes
#      33 # Notice that here edges go from cited to citing, so we are interested in out-degree
# ---> 34 total_out_degree = sum(dict(G.out_degree()).values())
#      36 # Create a list of existing nodes to connect to
#      37 targets = set()
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/classes/reportviews.py:561, in OutDegreeView.__iter__(self)
#     559     for n in self._nodes:
#     560         succs = self._succ[n]
# --> 561         yield (n, len(succs))
#     562 else:
#     563     for n in self._nodes:
#
# KeyboardInterrupt:

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('perceptron_citation_cleaned_lcc.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 3149

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 6.697681803747221
# 3.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.716698838595938
# approx_average_clustering_coefficient: 0.006434695049083823
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.720810199433867
#
#
# Randomization parameter p=0.25
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.5673862355054483
# approx_average_clustering_coefficient: 0.0019344894218286818
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.834791690311214
#
#
# Randomization parameter p=0.5
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.4249758704884197
# approx_average_clustering_coefficient: 0.0006368361007960829
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.7211112690795276
#
#
# Randomization parameter p=0.75
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.2985055956541749
# approx_average_clustering_coefficient: 0.00011316217305289898
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.5537930646574463
#
#
# Randomization parameter p=1
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.2201801839836958
# approx_average_clustering_coefficient: 0.002140583595369217
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.373121409343485

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('pepticulcer_citation_cleaned_lcc.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 19539

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 13.547162086084242
# 3.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.7600842542192718
# approx_average_clustering_coefficient: 0.001850740540059204
# diameter: 19540
# avg_path_length: 19540
# degree_entropy: 3.156581442829458
#
#
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.5888737936853057
# approx_average_clustering_coefficient: 0.00045028937680690164
# diameter: 19540
# avg_path_length: 19540
# degree_entropy: 3.4339233266590075
#
#
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.4209416938713727
# approx_average_clustering_coefficient: 0.0001340602208156981
# diameter: 19540
# avg_path_length: 19540
# degree_entropy: 3.3051723947961866
#
#
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.26183335747768527
# approx_average_clustering_coefficient: 4.623444439775434e-05
# diameter: 7
# avg_path_length: 4.032175038779396
# degree_entropy: 3.063043933237978
#
#
# Randomization parameter p=1
# Randomization done, calculating statistics...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       3 print(f'Randomization parameter p={p}')
#       4 print('Randomization done, calculating statistics...')
# ----> 5 stats = network_statistics(randomized_network)
#       6 for key in stats:
#       7   print(f"{key}: {stats[key]}")
#
# File ~/GitRepositories/e_network_inequality/network_utils.py:168, in network_statistics(G, directed)
#     166 if directed:
#     167     if nx.is_strongly_connected(G):
# --> 168         stats['diameter'] = nx.diameter(G)
#     169     else:
#     170         stats['diameter'] = len(G.nodes)+1
#
# File <class 'networkx.utils.decorators.argmap'> compilation 26:3, in argmap_diameter_23(G, e, usebounds, weight, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/algorithms/distance_measures.py:386, in diameter(G, e, usebounds, weight)
#     384     return _extrema_bounding(G, compute="diameter", weight=weight)
#     385 if e is None:
# --> 386     e = eccentricity(G, weight=weight)
#     387 return max(e.values())
#
# File <class 'networkx.utils.decorators.argmap'> compilation 30:3, in argmap_eccentricity_27(G, v, sp, weight, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/algorithms/distance_measures.py:308, in eccentricity(G, v, sp, weight)
#     306 for n in G.nbunch_iter(v):
#     307     if sp is None:
# --> 308         length = nx.shortest_path_length(G, source=n, weight=weight)
#     310         L = len(length)
#     311     else:
#
# File <class 'networkx.utils.decorators.argmap'> compilation 34:3, in argmap_shortest_path_length_31(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/algorithms/shortest_paths/generic.py:316, in shortest_path_length(G, source, target, weight, method)
#     313 if target is None:
#     314     # Find paths to all nodes accessible from the source.
#     315     if method == "unweighted":
# --> 316         paths = nx.single_source_shortest_path_length(G, source)
#     317     elif method == "dijkstra":
#     318         path_length = nx.single_source_dijkstra_path_length
#
# File <class 'networkx.utils.decorators.argmap'> compilation 38:3, in argmap_single_source_shortest_path_length_35(G, source, cutoff, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/algorithms/shortest_paths/unweighted.py:63, in single_source_shortest_path_length(G, source, cutoff)
#      61     cutoff = float("inf")
#      62 nextlevel = [source]
# ---> 63 return dict(_single_shortest_path_length(G._adj, nextlevel, cutoff))
#
# File ~/GitRepositories/e_network_inequality/.conda/lib/python3.11/site-packages/networkx/algorithms/shortest_paths/unweighted.py:92, in _single_shortest_path_length(adj, firstlevel, cutoff)
#      90 for w in adj[v]:
#      91     if w not in seen:
# ---> 92         seen.add(w)
#      93         nextlevel.append(w)
#      94         yield (w, level)
#
# KeyboardInterrupt:
