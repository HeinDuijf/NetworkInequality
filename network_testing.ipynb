# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_generation import *

# %% [markdown]
# # Generated Networks

# %%
for rdmize in [0,0.25,0.5,0.75,1]:
    G = barabasi_albert_directed(1000, 5)
    G = randomize_network(G, rdmize)
    plot_network_degree_distribution(G, title=f'Randomization: {rdmize}')
    plot_loglog(G,m=2)
    stats = network_statistics(G)
    for key in stats:
        print(f"{key}: {stats[key]}")
# Out:
# 4.985
# 0.0
# average_degree: 4.985
# degree_gini_coefficient: 0.8933193580742227
# approx_average_clustering_coefficient: 0.11090401090650231
# avg_path_length: 1001
# degree_entropy: 1.8263093061792404
# reachability_dominator_set_size: 1
# reachability_dominator_set_ratio: 0.001
# condensation_graph_size: 1000
# condensation_graph_ratio: 1.0
# 4.985
# 2.0
# average_degree: 4.985
# degree_gini_coefficient: 0.7152471414242727
# approx_average_clustering_coefficient: 0.059310806396623665
# avg_path_length: 1001
# degree_entropy: 2.228846925021844
# reachability_dominator_set_size: 1
# reachability_dominator_set_ratio: 0.001
# condensation_graph_size: 235
# condensation_graph_ratio: 0.235
# 4.985
# 3.0
# average_degree: 4.985
# degree_gini_coefficient: 0.5381779338014041
# approx_average_clustering_coefficient: 0.02345987914833871
# avg_path_length: 1001
# degree_entropy: 2.285132597103127
# reachability_dominator_set_size: 1
# reachability_dominator_set_ratio: 0.001
# condensation_graph_size: 50
# condensation_graph_ratio: 0.05
# 4.985
# 4.0
# average_degree: 4.985
# degree_gini_coefficient: 0.38871915747241725
# approx_average_clustering_coefficient: 0.010115952048541602
# avg_path_length: 1001
# degree_entropy: 2.2951545817376577
# reachability_dominator_set_size: 3
# reachability_dominator_set_ratio: 0.003
# condensation_graph_size: 18
# condensation_graph_ratio: 0.018
# 4.985
# 5.0
# average_degree: 4.985
# degree_gini_coefficient: 0.2503460381143431
# approx_average_clustering_coefficient: 0.004612264562239326
# avg_path_length: 1001
# degree_entropy: 2.199437614317636
# reachability_dominator_set_size: 6
# reachability_dominator_set_ratio: 0.006
# condensation_graph_size: 20
# condensation_graph_ratio: 0.02

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/perceptron_final.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 89

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G,m=2)
# Out:
# 1.752808988764045
# 0.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.8362143474503024
# approx_average_clustering_coefficient: 0.14374528821767243
# avg_path_length: 90
# degree_entropy: 1.3843532403961119
# reachability_dominator_set_size: 8
# reachability_dominator_set_ratio: 0.0898876404494382
# condensation_graph_size: 86
# condensation_graph_ratio: 0.9662921348314607
#
#
# Randomization parameter p=0.25
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.7082973206568712
# approx_average_clustering_coefficient: 0.09965650835260799
# avg_path_length: 90
# degree_entropy: 1.5927671680259268
# reachability_dominator_set_size: 12
# reachability_dominator_set_ratio: 0.1348314606741573
# condensation_graph_size: 74
# condensation_graph_ratio: 0.8314606741573034
#
#
# Randomization parameter p=0.5
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.567559781042927
# approx_average_clustering_coefficient: 0.022353229681385665
# avg_path_length: 90
# degree_entropy: 1.6444860283400204
# reachability_dominator_set_size: 16
# reachability_dominator_set_ratio: 0.1797752808988764
# condensation_graph_size: 63
# condensation_graph_ratio: 0.7078651685393258
#
#
# Randomization parameter p=0.75
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.40723134543359263
# approx_average_clustering_coefficient: 0.010045478865703587
# avg_path_length: 90
# degree_entropy: 1.5680000999803465
# reachability_dominator_set_size: 16
# reachability_dominator_set_ratio: 0.1797752808988764
# condensation_graph_size: 49
# condensation_graph_ratio: 0.550561797752809
#
#
# Randomization parameter p=1
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.3769806972054163
# approx_average_clustering_coefficient: 0.012047440699126095
# avg_path_length: 90
# degree_entropy: 1.5299010902607981
# reachability_dominator_set_size: 15
# reachability_dominator_set_ratio: 0.16853932584269662
# condensation_graph_size: 47
# condensation_graph_ratio: 0.5280898876404494

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/pud_final.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 5493

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 4.034043327871837
# 1.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.7228139589628397
# approx_average_clustering_coefficient: 0.11717045132746481
# avg_path_length: 5494
# degree_entropy: 2.3458045313729907
# reachability_dominator_set_size: 1029
# reachability_dominator_set_ratio: 0.18732932823593665
# condensation_graph_size: 3695
# condensation_graph_ratio: 0.6726743127616968
#
#
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.5880115219443226
# approx_average_clustering_coefficient: 0.0375421693215293
# avg_path_length: 5494
# degree_entropy: 2.4095599048489356
# reachability_dominator_set_size: 507
# reachability_dominator_set_ratio: 0.0922992900054615
# condensation_graph_size: 1571
# condensation_graph_ratio: 0.2860003640997633
#
#
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.46328240216983674
# approx_average_clustering_coefficient: 0.011678483285896431
# avg_path_length: 5494
# degree_entropy: 2.3688970203557864
# reachability_dominator_set_size: 259
# reachability_dominator_set_ratio: 0.04715091935190242
# condensation_graph_size: 711
# condensation_graph_ratio: 0.1294374658656472
#
#
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.34160199968802013
# approx_average_clustering_coefficient: 0.0023984355684169923
# avg_path_length: 5494
# degree_entropy: 2.235899560918364
# reachability_dominator_set_size: 155
# reachability_dominator_set_ratio: 0.028217731658474424
# condensation_graph_size: 356
# condensation_graph_ratio: 0.06480975787365738
#
#
# Randomization parameter p=1
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.2744218059527362
# approx_average_clustering_coefficient: 0.0007212382015607503
# avg_path_length: 5494
# degree_entropy: 2.0838202642333066
# reachability_dominator_set_size: 110
# reachability_dominator_set_ratio: 0.02002548698343346
# condensation_graph_size: 229
# condensation_graph_ratio: 0.04168942290187511
