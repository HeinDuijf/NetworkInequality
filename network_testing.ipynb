# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_randomization import *
from network_generation import *

# %% [markdown]
# # Generated Networks

# %%
for rdmize in [0,0.25,0.5,0.75,1]:
    G = barabasi_albert_directed(1000, 5)
    G = randomize_network(G, rdmize)
    plot_network_degree_distribution(G, title=f'Randomization: {rdmize}')
    plot_loglog(G,m=2)
    stats = network_statistics(G)
    for key in stats:
        print(f"{key}: {stats[key]}")
# Out:
# 4.985
# 0.0
# average_degree: 4.985
# degree_gini_coefficient: 0.8996387161484454
# approx_average_clustering_coefficient: 0.13752350656724688
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 1.7960834134389145
# 4.985
# 2.0
# average_degree: 4.985
# degree_gini_coefficient: 0.7339448345035104
# approx_average_clustering_coefficient: 0.05603675882558763
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.170957133372046
# 4.985
# 3.0
# average_degree: 4.985
# degree_gini_coefficient: 0.5528158475426278
# approx_average_clustering_coefficient: 0.024313833319424192
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.290925896015466
# 4.985
# 4.0
# average_degree: 4.985
# degree_gini_coefficient: 0.39508264794383147
# approx_average_clustering_coefficient: 0.009250222515196594
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.3176835276140832
# 4.985
# 5.0
# average_degree: 4.985
# degree_gini_coefficient: 0.25564192577733197
# approx_average_clustering_coefficient: 0.004806667047263024
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.221317683455587

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/perc_pruned_lcc.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 138

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G,m=2)
# Out:
# 2.152173913043478
# 0.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# average_degree: 2.152173913043478
# degree_gini_coefficient: 0.7949299760893963
# approx_average_clustering_coefficient: 0.10567247157524103
# diameter: 139
# avg_path_length: 139
# degree_entropy: 1.6086319251684362
#
#
# Randomization parameter p=0.25
# average_degree: 2.152173913043478
# degree_gini_coefficient: 0.6936270921778167
# approx_average_clustering_coefficient: 0.056905403634001685
# diameter: 139
# avg_path_length: 139
# degree_entropy: 1.7555171512108163
#
#
# Randomization parameter p=0.5
# average_degree: 2.152173913043478
# degree_gini_coefficient: 0.5532864880690969
# approx_average_clustering_coefficient: 0.04805633398628566
# diameter: 139
# avg_path_length: 139
# degree_entropy: 1.774609371086487
#
#
# Randomization parameter p=0.75
# average_degree: 2.152173913043478
# degree_gini_coefficient: 0.43163519250475774
# approx_average_clustering_coefficient: 0.017142016598538333
# diameter: 139
# avg_path_length: 139
# degree_entropy: 1.796109803797355
#
#
# Randomization parameter p=1
# average_degree: 2.152173913043478
# degree_gini_coefficient: 0.3831796223100571
# approx_average_clustering_coefficient: 0.015365874061526239
# diameter: 139
# avg_path_length: 139
# degree_entropy: 1.7567705750567435

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/pud_pruned_lcc.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 6795

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 4.692715231788079
# 2.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.692715231788079
# degree_gini_coefficient: 0.721041320651409
# approx_average_clustering_coefficient: 0.10878794634084789
# diameter: 6796
# avg_path_length: 6796
# degree_entropy: 2.4634767931480868
#
#
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 4.692715231788079
# degree_gini_coefficient: 0.5849084768225766
# approx_average_clustering_coefficient: 0.03506614934817548
# diameter: 6796
# avg_path_length: 6796
# degree_entropy: 2.5283069042464397
#
#
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# average_degree: 4.692715231788079
# degree_gini_coefficient: 0.4543263505951491
# approx_average_clustering_coefficient: 0.010472449221453243
# diameter: 6796
# avg_path_length: 6796
# degree_entropy: 2.4718693568026286
#
#
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# average_degree: 4.692715231788079
# degree_gini_coefficient: 0.3303499459656021
# approx_average_clustering_coefficient: 0.002451044896164537
# diameter: 6796
# avg_path_length: 6796
# degree_entropy: 2.335494873042277
#
#
# Randomization parameter p=1
# Randomization done, calculating statistics...
# average_degree: 4.692715231788079
# degree_gini_coefficient: 0.254770094718904
# approx_average_clustering_coefficient: 0.0006847373355596262
# diameter: 6796
# avg_path_length: 6796
# degree_entropy: 2.1637675943120476
