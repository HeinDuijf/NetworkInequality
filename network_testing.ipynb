# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_generation import *

# %% [markdown]
# # Generated Networks

# %%
for rdmize in [0,0.25,0.5,0.75,1]:
    G = barabasi_albert_directed(1000, 5)
    G = randomize_network(G, rdmize)
    plot_network_degree_distribution(G, title=f'Randomization: {rdmize}')
    plot_loglog(G,m=2)
    stats = network_statistics(G)
    for key in stats:
        print(f"{key}: {stats[key]}")

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/perceptron_final.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G,m=2)

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/pud_final.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 5493

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 1.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
tot_edges = len(G.edges())
print(f"Total edges in the network: {tot_edges}")
int(1 * tot_edges)
# Out:
# Total edges in the network: 22159
# 22159

# %%
tot_edges = len(G.edges())
for p in [0,0.25,0.5,0.75,1]:
  frac_edges = int(p * tot_edges)
  randomized_network = randomize_network(G,n_edges=frac_edges)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.7228139589628397
# approx_average_clustering_coefficient: 0.11717045132746483
# avg_path_length: 5494
# degree_entropy: 2.3458045313729907
# reachability_dominator_set_size: 1029
# reachability_dominator_set_ratio: 0.18732932823593665
# condensation_graph_size: 3695
# condensation_graph_ratio: 0.6726743127616968
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 1.0
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.5857682309885441
# approx_average_clustering_coefficient: 0.03862608732029347
# avg_path_length: 5494
# degree_entropy: 2.4132603984005887
# reachability_dominator_set_size: 514
# reachability_dominator_set_ratio: 0.09357363917713453
# condensation_graph_size: 1639
# condensation_graph_ratio: 0.2983797560531586
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 2.0
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.4558524107585261
# approx_average_clustering_coefficient: 0.011360446203216336
# avg_path_length: 5494
# degree_entropy: 2.358591227260409
# reachability_dominator_set_size: 250
# reachability_dominator_set_ratio: 0.04551247041689423
# condensation_graph_size: 672
# condensation_graph_ratio: 0.1223375204806117
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 3.0
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.3432019091584811
# approx_average_clustering_coefficient: 0.002816191716301415
# avg_path_length: 5494
# degree_entropy: 2.2358308759492926
# reachability_dominator_set_size: 144
# reachability_dominator_set_ratio: 0.026215182960131075
# condensation_graph_size: 331
# condensation_graph_ratio: 0.06025851083196796
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 4.0
# Randomization parameter p=1
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.27475296108745606
# approx_average_clustering_coefficient: 0.0005585392360792967
# avg_path_length: 5494
# degree_entropy: 2.0860440672222706
# reachability_dominator_set_size: 91
# reachability_dominator_set_ratio: 0.0165665392317495
# condensation_graph_size: 197
# condensation_graph_ratio: 0.03586382668851265
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 4.0
