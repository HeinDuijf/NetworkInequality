# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_generation import *

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/pud_final.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 5493

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 1.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %% [markdown]
# ## Randomize

# %%
tot_edges = len(G.edges())
for p in [0,0.25,0.5,0.75,1]:
  print('\n')
  frac_edges = int(p * tot_edges)
  randomized_network = randomize_network(G,n_edges=frac_edges)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.7228139589628397
# approx_average_clustering_coefficient: 0.11717045132746483
# avg_path_length: 5494
# degree_entropy: 2.3458045313729907
# reachability_dominator_set_size: 1029
# reachability_dominator_set_ratio: 0.18732932823593665
# condensation_graph_size: 3695
# condensation_graph_ratio: 0.6726743127616968
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 1.0
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.589058175260117
# approx_average_clustering_coefficient: 0.038738821754396004
# avg_path_length: 5494
# degree_entropy: 2.4165774743314654
# reachability_dominator_set_size: 503
# reachability_dominator_set_ratio: 0.0915710904787912
# condensation_graph_size: 1615
# condensation_graph_ratio: 0.2940105588931367
# ...

# %% [markdown]
# ## Equalize

# %%
tot_edges = len(G.edges())
for p in [0,0.25,0.5,0.75,1]:
  frac_edges = int(p * tot_edges)
  randomized_network = equalize(G,n =frac_edges)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.7228139589628397
# approx_average_clustering_coefficient: 0.11717045132746483
# avg_path_length: 5494
# degree_entropy: 2.3458045313729907
# reachability_dominator_set_size: 1029
# reachability_dominator_set_ratio: 0.18732932823593665
# condensation_graph_size: 3695
# condensation_graph_ratio: 0.6726743127616968
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 1.0
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.6825726619868698
# approx_average_clustering_coefficient: 0.08723208538756984
# avg_path_length: 5494
# degree_entropy: 2.398855166338697
# reachability_dominator_set_size: 904
# reachability_dominator_set_ratio: 0.16457309302748954
# condensation_graph_size: 2900
# condensation_graph_ratio: 0.527944656835973
# ...

# %% [markdown]
# ## Densify 1

# %%
tot_edges = len(G.edges())
for p in [0,0.25,0.5,0.75,1]:
  frac_edges = int(p * tot_edges)
  randomized_network = densify_fancy_speed_up(G,frac_edges,
                                              target_degree_dist='original',
                                              keep_density_fixed=False)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.7228139589628397
# approx_average_clustering_coefficient: 0.11717045132746483
# avg_path_length: 5494
# degree_entropy: 2.3458045313729907
# reachability_dominator_set_size: 1029
# reachability_dominator_set_ratio: 0.18732932823593665
# condensation_graph_size: 3695
# condensation_graph_ratio: 0.6726743127616968
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 1.0
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 5.0424176224285455
# degree_gini_coefficient: 0.7205500401412825
# approx_average_clustering_coefficient: 0.11718774141983626
# avg_path_length: 5494
# degree_entropy: 2.5269398864243846
# reachability_dominator_set_size: 926
# reachability_dominator_set_ratio: 0.1685781904241762
# condensation_graph_size: 3171
# condensation_graph_ratio: 0.5772801747678864
# ...

# %% [markdown]
# ## Densify 2

# %%
tot_edges = len(G.edges())
for p in [0,0.25,0.5,0.75,1]:
  frac_edges = int(p * tot_edges)
  randomized_network = densify_fancy_speed_up(G,frac_edges,
                                              target_degree_dist='uniform',
                                              keep_density_fixed=True)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  plot_network_degree_distribution(randomized_network)
  plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.7228139589628397
# approx_average_clustering_coefficient: 0.11717045132746483
# avg_path_length: 5494
# degree_entropy: 2.3458045313729907
# reachability_dominator_set_size: 1029
# reachability_dominator_set_ratio: 0.18732932823593665
# condensation_graph_size: 3695
# condensation_graph_ratio: 0.6726743127616968
# Density of the network: 0.0007345308317319441
# 4.034043327871837
# 1.0
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.6418906628243207
# approx_average_clustering_coefficient: 0.11717314578407688
# avg_path_length: 5494
# degree_entropy: 2.414773929548911
# reachability_dominator_set_size: 673
# reachability_dominator_set_ratio: 0.12251957036227927
# condensation_graph_size: 2027
# condensation_graph_ratio: 0.3690151101401784
# ...
