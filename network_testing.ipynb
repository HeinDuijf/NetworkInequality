# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_randomization import *
from network_generation import *

# %% [markdown]
# # Generated Networks

# %%
for rdmize in [0,0.25,0.5,0.75,1]:
    G = barabasi_albert_directed(1000, 5)
    G = randomize_network(G, rdmize)
    plot_network_degree_distribution(G, title=f'Randomization: {rdmize}')
    plot_loglog(G,m=2)
    stats = network_statistics(G)
    for key in stats:
        print(f"{key}: {stats[key]}")
# Out:
# 4.985
# 0.0
# average_degree: 4.985
# degree_gini_coefficient: 0.9005414242728184
# approx_average_clustering_coefficient: 0.15157359869660275
# avg_path_length: 1001
# degree_entropy: 1.7949305309129393
# reachability_dominator_set_size: 1
# reachability_dominator_set_ratio: 0.001
# condensation_graph_size: 1000
# condensation_graph_ratio: 1.0
# 4.985
# 2.0
# average_degree: 4.985
# degree_gini_coefficient: 0.7385562688064192
# approx_average_clustering_coefficient: 0.05569952481745227
# avg_path_length: 1001
# degree_entropy: 2.219855585106843
# reachability_dominator_set_size: 2
# reachability_dominator_set_ratio: 0.002
# condensation_graph_size: 266
# condensation_graph_ratio: 0.266
# 4.985
# 3.0
# average_degree: 4.985
# degree_gini_coefficient: 0.5626978936810431
# approx_average_clustering_coefficient: 0.02511630983682843
# avg_path_length: 1001
# degree_entropy: 2.305074798531385
# reachability_dominator_set_size: 4
# reachability_dominator_set_ratio: 0.004
# condensation_graph_size: 74
# condensation_graph_ratio: 0.074
# 4.985
# 4.0
# average_degree: 4.985
# degree_gini_coefficient: 0.3908150451354062
# approx_average_clustering_coefficient: 0.01034228637948913
# avg_path_length: 1001
# degree_entropy: 2.305899294765064
# reachability_dominator_set_size: 6
# reachability_dominator_set_ratio: 0.006
# condensation_graph_size: 33
# condensation_graph_ratio: 0.033
# 4.985
# 5.0
# average_degree: 4.985
# degree_gini_coefficient: 0.2493269809428285
# approx_average_clustering_coefficient: 0.004500183638457634
# avg_path_length: 1001
# degree_entropy: 2.195341894390694
# reachability_dominator_set_size: 12
# reachability_dominator_set_ratio: 0.012
# condensation_graph_size: 17
# condensation_graph_ratio: 0.017

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/perceptron_final.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 89

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G,m=2)
# Out:
# 1.752808988764045
# 0.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.8362143474503024
# approx_average_clustering_coefficient: 0.14374528821767243
# avg_path_length: 90
# degree_entropy: 1.3843532403961119
# reachability_dominator_set_size: 8
# reachability_dominator_set_ratio: 0.0898876404494382
# condensation_graph_size: 86
# condensation_graph_ratio: 0.9662921348314607
#
#
# Randomization parameter p=0.25
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.6960530106597522
# approx_average_clustering_coefficient: 0.08358352425768156
# avg_path_length: 90
# degree_entropy: 1.5649591990683938
# reachability_dominator_set_size: 10
# reachability_dominator_set_ratio: 0.11235955056179775
# condensation_graph_size: 69
# condensation_graph_ratio: 0.7752808988764045
#
#
# Randomization parameter p=0.5
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.6153846153846153
# approx_average_clustering_coefficient: 0.01959753729416651
# avg_path_length: 90
# degree_entropy: 1.6712739656487843
# reachability_dominator_set_size: 16
# reachability_dominator_set_ratio: 0.1797752808988764
# condensation_graph_size: 53
# condensation_graph_ratio: 0.5955056179775281
#
#
# Randomization parameter p=0.75
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.47968885047536736
# approx_average_clustering_coefficient: 0.010299355243175469
# avg_path_length: 90
# degree_entropy: 1.6059416856074593
# reachability_dominator_set_size: 16
# reachability_dominator_set_ratio: 0.1797752808988764
# condensation_graph_size: 61
# condensation_graph_ratio: 0.6853932584269663
#
#
# Randomization parameter p=1
# average_degree: 1.752808988764045
# degree_gini_coefficient: 0.40636704119850187
# approx_average_clustering_coefficient: 0.009242910647405032
# avg_path_length: 90
# degree_entropy: 1.6008125640609174
# reachability_dominator_set_size: 18
# reachability_dominator_set_ratio: 0.20224719101123595
# condensation_graph_size: 42
# condensation_graph_ratio: 0.47191011235955055

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('./empirical_networks/pud_final.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 5493

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 4.034043327871837
# 1.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.7228139589628397
# approx_average_clustering_coefficient: 0.11717045132746481
# avg_path_length: 5494
# degree_entropy: 2.3458045313729907
# reachability_dominator_set_size: 1029
# reachability_dominator_set_ratio: 0.18732932823593665
# condensation_graph_size: 3695
# condensation_graph_ratio: 0.6726743127616968
#
#
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.5896660159814969
# approx_average_clustering_coefficient: 0.038710058878128596
# avg_path_length: 5494
# degree_entropy: 2.4251945781942186
# reachability_dominator_set_size: 506
# reachability_dominator_set_ratio: 0.09211724012379392
# condensation_graph_size: 1612
# condensation_graph_ratio: 0.293464409248134
#
#
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.4578261308529265
# approx_average_clustering_coefficient: 0.01204307734757782
# avg_path_length: 5494
# degree_entropy: 2.3556523712940582
# reachability_dominator_set_size: 252
# reachability_dominator_set_ratio: 0.045876570180229385
# condensation_graph_size: 684
# condensation_graph_ratio: 0.1245221190606226
#
#
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.3436695257099841
# approx_average_clustering_coefficient: 0.0025623706392061078
# avg_path_length: 5494
# degree_entropy: 2.2359176944245696
# reachability_dominator_set_size: 148
# reachability_dominator_set_ratio: 0.026943382486801382
# condensation_graph_size: 340
# condensation_graph_ratio: 0.06189695976697615
#
#
# Randomization parameter p=1
# Randomization done, calculating statistics...
# average_degree: 4.034043327871837
# degree_gini_coefficient: 0.2774237599471315
# approx_average_clustering_coefficient: 0.0007545409023521607
# avg_path_length: 5494
# degree_entropy: 2.0955769056745788
# reachability_dominator_set_size: 99
# reachability_dominator_set_ratio: 0.018022938285090113
# condensation_graph_size: 226
# condensation_graph_ratio: 0.041143273256872386
