# %% [markdown]
# # Setup

# %%
from imports import *
from network_utils import *
from network_randomization import *
from network_generation import *

# %% [markdown]
# # Generated Networks

# %%
for rdmize in [0,0.25,0.5,0.75,1]:
    G = barabasi_albert_directed(1000, 5)
    G = randomize_network(G, rdmize)
    plot_network_degree_distribution(G, title=f'Randomization: {rdmize}')
    plot_loglog(G,m=2)
    stats = network_statistics(G)
    for key in stats:
        print(f"{key}: {stats[key]}")
# Out:
# 4.985
# 0.0
# average_degree: 4.985
# degree_gini_coefficient: 0.8959857572718155
# approx_average_clustering_coefficient: 0.1401499422187831
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 1.8246056510393482
# 4.985
# 2.0
# average_degree: 4.985
# degree_gini_coefficient: 0.7360836509528585
# approx_average_clustering_coefficient: 0.06511696057843692
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.2023675771657443
# 4.985
# 3.0
# average_degree: 4.985
# degree_gini_coefficient: 0.5512487462387162
# approx_average_clustering_coefficient: 0.023884125696501553
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.2855950758208707
# 4.985
# 4.0
# average_degree: 4.985
# degree_gini_coefficient: 0.37518054162487463
# approx_average_clustering_coefficient: 0.0088873523387112
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.2751087496757147
# 4.985
# 5.0
# average_degree: 4.985
# degree_gini_coefficient: 0.25805436308926777
# approx_average_clustering_coefficient: 0.005166285917098611
# diameter: 1001
# avg_path_length: 1001
# degree_entropy: 2.2361425441988407

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Load

# %%
with open('perceptron_citation_cleaned_lcc.pkl', 'rb') as f:
  G_perceptron = pickle.load(f)

n_agents = G_perceptron.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_perceptron.nodes())}

# Relabel the nodes in the graph
G_perceptron_indexed = nx.relabel_nodes(G_perceptron, mapping)
G = G_perceptron_indexed
# Out:
# 3149

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 6.697681803747221
# 3.0

# %% [markdown]
# ## Randomize, Plot, and Stats

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.716698838595938
# approx_average_clustering_coefficient: 0.006434695049083823
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.720810199433867
#
#
# Randomization parameter p=0.25
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.5677442239099425
# approx_average_clustering_coefficient: 0.0019109031250312029
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.833435888842433
#
#
# Randomization parameter p=0.5
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.4245338957397016
# approx_average_clustering_coefficient: 0.0011390301723670057
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.729341049554235
#
#
# Randomization parameter p=0.75
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.2944368803701555
# approx_average_clustering_coefficient: 0.0001302843088477118
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.5414975112878695
#
#
# Randomization parameter p=1
# average_degree: 6.697681803747221
# degree_gini_coefficient: 0.2181309954795381
# approx_average_clustering_coefficient: 0.0021616071064662896
# diameter: 3150
# avg_path_length: 3150
# degree_entropy: 2.364040739126826

# %% [markdown]
# # Peptic Ulcer

# %% [markdown]
# ## Load

# %%
with open('pepticulcer_citation_cleaned_lcc.pkl', 'rb') as f:
  G_pepticulcer = pickle.load(f)

n_agents = G_pepticulcer.number_of_nodes()
print(n_agents)

# Create a mapping from node names to indexes
mapping = {node: index for index, node in enumerate(G_pepticulcer.nodes())}

# Relabel the nodes in the graph
G_pepticulcer_indexed = nx.relabel_nodes(G_pepticulcer, mapping)
G = G_pepticulcer_indexed
# Out:
# 19539

# %% [markdown]
# ## Plot

# %%
plot_network_degree_distribution(G)
plot_loglog(G)
# Out:
# 13.547162086084242
# 3.0

# %% [markdown]
# ## Randomize, Stats, and Plot

# %%
for p in [0,0.25,0.5,0.75,1]:
  randomized_network = randomize_network(G,p_rewiring=p)
  print(f'Randomization parameter p={p}')
  print('Randomization done, calculating statistics...')
  stats = network_statistics(randomized_network)
  for key in stats:
    print(f"{key}: {stats[key]}")
  #plot_network_degree_distribution(randomized_network)
  #plot_loglog(randomized_network)
  print('\n')
# Out:
# Randomization parameter p=0
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.7600842542192718
# approx_average_clustering_coefficient: 0.001850740540059204
# diameter: 19540
# avg_path_length: 19540
# degree_entropy: 3.156581442829458
#
#
# Randomization parameter p=0.25
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.5892975991526445
# approx_average_clustering_coefficient: 0.0004446376780862876
# diameter: 19540
# avg_path_length: 19540
# degree_entropy: 3.4344396226521865
#
#
# Randomization parameter p=0.5
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.4218526938566312
# approx_average_clustering_coefficient: 0.00016334063891639054
# diameter: 19540
# avg_path_length: 19540
# degree_entropy: 3.308955388347008
#
#
# Randomization parameter p=0.75
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.2616585613644334
# approx_average_clustering_coefficient: 3.2051976606804725e-05
# diameter: 7
# avg_path_length: 4.031766989576521
# degree_entropy: 3.0607976005278563
#
#
# Randomization parameter p=1
# Randomization done, calculating statistics...
# average_degree: 13.547162086084242
# degree_gini_coefficient: 0.15330348027771185
# approx_average_clustering_coefficient: 0.0006762832923264684
# diameter: 6
# avg_path_length: 4.059418257537017
# degree_entropy: 2.7189854998930203
